# %%
import pandas as pd
import numpy as np

# %%
import time
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit
from scipy.optimize import leastsq
import scipy.optimize as opt
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import gc

from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import MinMaxScaler
import os
from data_preprocessing import FilteringCurves, ShowResponseCurves
from fitting_curves import FittingColumn, ShowResponseCurvesWithFitting, compute_r2_score

# from IPython.display import display
#_FOLDER = "results/"
_FOLDER = "/home/acq18mk/master/results/"

### Coding Part

def LeaveOneOutError(kernel_model, X, y, metrics = "mse"):
    errors = []
    splitter_loo = LeaveOneOut()
#     print(splitter_loo.get_n_splits(X))
    
    for train_index, test_index in splitter_loo.split(X):
        X_train_loo, X_test_loo = X[train_index, :], X[test_index,:]
        y_train_loo, y_test_loo = y[train_index], y[test_index]
        
        model = kernel_model.fit(X_train_loo, y_train_loo)
        if metrics == "mse":
            mse = mean_squared_error(y_test_loo, model.predict(X_test_loo))
            errors.append(mse)
        elif metrics == "mae":
            mae = mean_absolute_error(y_test_loo, model.predict(X_test_loo))
            errors.append(mae)
    
    return (sum(errors)/ len(errors)) 

# gamma for RBF, laplacian, polynomial, exponential chi2 and sigmoid kernels

def RunCrossValidation(merged_df, drug_ids, number_coefficients, train_ratio=0.8, column_not_to_use =[], kernel='linear', param_tested = "alpha", 
                       param_tested_values = [], alpha=1, gamma=None, degree=3, coef0=1,features_to_scale=[], scaling=False, 
                      print_results=True):
    
    param1 = ["param_" +str(i) for i in range(10)]
    param2 = ["param" +str(i) for i in range(10)] 
    norm_response  = ["norm_cells_"+str(i) for i in range(10)]
    con_columns  = ["fd_num_"+str(i) for i in range(10)]
    not_X_columns = param1 + param2 + norm_response + con_columns+column_not_to_use
    X_columns = set(df.columns) - set(not_X_columns)
    print("Number of X_columns:", len(X_columns))
    
    df_errors = pd.DataFrame()
    #check whether each coefficient needs its own parameters
    

    for drug_id in drug_ids:
        merged_df_i = merged_df[merged_df["DRUG_ID"]==drug_id]
        # merged_df_i has lower shape
        np.random.seed(123)
        indexes = np.random.permutation(merged_df_i.index)
        train_size = int(merged_df_i.shape[0]*train_ratio)
        indexes_train = indexes[:train_size]
        if scaling:
            train=merged_df_i.loc[indexes_train, X_columns].copy()
            scaler = MinMaxScaler()
            train[columns_for_normalisation] = scaler.fit_transform(train[columns_for_normalisation])
            X_train = train.values     
        else:
            X_train = merged_df_i.loc[indexes_train, X_columns].values
    
        for i in range(number_coefficients):
            #check whether each coefficient needs its own parameters
            if type(alpha)==dict:
                alpha_value = alpha[i+1]
            else:
                alpha_value = alpha
                
            if type(gamma)==dict:
                gamma_value = gamma[i+1]
            else:
                gamma_value = gamma
            
            if type(degree)==dict:
                degree_value = degree[i+1]
            else:
                degree_value = degree
                
            if type(coef0)==dict:
                coef0_value = coef0[i+1]
            else:
                coef0_value = coef0
            
            y_train = merged_df_i.loc[indexes_train, "param_"+str(i+1)].values

            for param in param_tested_values:
    
                #check whether each coefficient needs its own parameters
                if param_tested == "alpha":
                    kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=param, 
                                               gamma=gamma_value, 
                                               degree=degree_value, 
                                               coef0=coef0_value)
                elif param_tested == "gamma":
                    kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value, 
                                               gamma=param, 
                                               degree=degree_value,
                                               coef0=coef0_value)
                elif param_tested == "degree":
                    kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value, 
                                               gamma=gamma_value,
                                               degree=param, 
                                               coef0=coef0_value)
                elif param_tested == "coef0":
                    kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value,  
                                               gamma=gamma_value,
                                               degree=degree_value,
                                               coef0=param)
                else:
                    print("ERROR: Unknown parameters")
                
                # mse is more sensitive to different parameters choice
                mse = LeaveOneOutError(kernel_model, X_train, y_train, metrics="mse")
                df_errors.loc[drug_id, "mse_coef"+str(i+1)+"_"+str(param)] = mse

        
    best_values = {}
    for coef in range(number_coefficients):
        df_results = df_errors[["mse_coef"+str(coef+1)+"_"+str(param) for param in param_tested_values]].describe().loc[["mean", "min","max"], :]
        best_param = np.float32(df_results.loc["mean",:].idxmin().split("_")[-1])
        best_values[coef+1] = best_param
        if print_results:
            print(df_results)
            print("Coefficient %d: ,  Best %s: %.5f" % (coef+1, param_tested, best_param))
        
    del df_errors
    print("%s kernel, best values for parameter: %s" % (kernel, param_tested))
    print(best_values)
    return best_values

def TestTunedKernels(merged_df, drug_ids, number_coefficients, kernel, train_ratio =0.8, column_not_to_use =[], alpha=1, gamma=None, degree=3, coef0=1, 
                     metrics = "mse", features_to_scale=[], scaling=False, print_results=True):
    """Training and testing Kernels with the best found hyperparameters"""
    
    param1 = ["param_" +str(i) for i in range(10)]
    param2 = ["param" +str(i) for i in range(10)] 
    norm_response  = ["norm_cells_"+str(i) for i in range(10)]
    con_columns  = ["fd_num_"+str(i) for i in range(10)]

    not_X_columns = param1 + param2 + norm_response + con_columns+column_not_to_use
    X_columns = set(df.columns) - set(not_X_columns)
    print("Number of X_columns:", len(X_columns))
    
    df_errors_test = pd.DataFrame()

    for drug_id in drug_ids:
        # merged_df_i has lower shape
        merged_df_i = merged_df[merged_df["DRUG_ID"]==drug_id]
        
        np.random.seed(123)
        indexes = np.random.permutation(merged_df_i.index)
        train_size = int(merged_df_i.shape[0]*train_ratio)
        indexes_train = indexes[:train_size]
        indexes_test= indexes[train_size:]
        
        if scaling:
            train = merged_df_i.loc[indexes_train, X_columns].copy()
            test = merged_df_i.loc[indexes_test, X_columns].copy()
            scaler = MinMaxScaler()
            scaler.fit(train[columns_for_normalisation])
            train[columns_for_normalisation] = scaler.transform(train[columns_for_normalisation])
            X_train = train.values  
            test[columns_for_normalisation] = scaler.transform(test[columns_for_normalisation])
            X_test = test.values
        else:
            X_train = merged_df_i.loc[indexes_train, X_columns].values
            X_test = merged_df_i.loc[indexes_test, X_columns].values
    
        for i in range(number_coefficients):
#             param = best_param[i+1]
            y_train = merged_df_i.loc[indexes_train, "param_"+str(i+1)].values
            y_test = merged_df_i.loc[indexes_test, "param_"+str(i+1)].values
            
            #check whether each coefficient needs its own parameters
            if type(alpha)==dict:
                alpha_value = alpha[i+1]
            else:
                alpha_value = alpha
                
            if type(gamma)==dict:
                gamma_value = gamma[i+1]
            else:
                gamma_value = gamma
            
            if type(degree)==dict:
                degree_value = degree[i+1]
            else:
                degree_value = degree
                
            if type(coef0)==dict:
                coef0_value = coef0[i+1]
            else:
                coef0_value = coef0
                
            kr_lin = KernelRidge(kernel = kernel, alpha = alpha_value, gamma=gamma_value, 
                                 degree=degree_value, coef0=coef0_value)
            kr_lin.fit(X_train, y_train)
            y_pred = kr_lin.predict(X_test)
                                
            # mse is more sensitive to different parameters choice
            if metrics == "mse":
                error = mean_squared_error(y_test, y_pred)
            elif metrics == "mae":
                error = mean_absolute_error(y_test, y_pred)
            else:
                print("ERROR: Unknown metrics")
            df_errors_test.loc[drug_id, kernel+"_mse_coef"+str(i+1)] = error
    
    df_results = df_errors_test.describe().loc[["mean", "min","max"], :]
    if print_results: 
        print(df_results)
    return df_results


def TuneParameters(merged_df, drug_ids, number_coefficients, kernels = [], column_not_to_use =[], param_tested = "alpha", 
                       param_tested_values = [], alpha=1, gamma=None, degree=3, coef0=1, features_to_scale=[], scaling=False, 
                      print_results=True):
    results = {}
    for kernel in kernels:
        start_time = time.time()
        if kernel == "linear":
            best_alpha = RunCrossValidation(merged_df, drug_ids, 4, kernel=kernel, column_not_to_use=column_not_to_use, 
                                            param_tested = "alpha", param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500],
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)
            
            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            
        elif kernel == "polynomial":
            start_time = time.time()
            best_gamma = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "gamma", 
                                            param_tested_values = [0.00001, 0.0001, 0.01, 0.1, 1], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            best_degree = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "degree", 
                                             gamma= best_gamma, param_tested_values = [1,2,3,4,5], 
                                             features_to_scale = features_to_scale, scaling = scaling,
                                             print_results=print_results)

            best_alpha = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "alpha", 
                                            gamma= best_gamma, degree = best_degree,
                                            param_tested_values = [0.001, 0.01, 0.1, 1, 5, 7], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)            
            
            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            results[kernel]["gamma"] = best_gamma
            results[kernel]["degree"] = best_degree
            
        else: 
            start_time = time.time()
            best_gamma = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel = kernel, column_not_to_use=column_not_to_use, param_tested = "gamma", 
                                            param_tested_values = [0.00001, 0.0001, 0.01, 0.1, 0.5, 1], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            
            best_alpha = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use, param_tested = "alpha", 
                                            param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)
            
            best_coef0 = RunCrossValidation(merged_df, drug_ids, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use, gamma= best_gamma, 
                                            param_tested = "coef0", alpha=best_alpha,
                                            param_tested_values = [-0.1, 0, 0.1, 0.5, 1,  5, 10], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            results[kernel]["gamma"] = best_gamma
            results[kernel]["coef0"] = best_coef0
            
    return  results

def TrainTestBestParameters(merged_df, drug_ids, number_coefficients, kernels =[], column_not_to_use =[], best_parameters_dict={}, 
                     metrics = "mse", features_to_scale=[], scaling=False, print_results=True):
    tests={}
    for kernel in kernels:
        if kernel == "linear":
            tests["linear"] = TestTunedKernels(merged_df, drug_ids, number_coefficients, kernel='linear', column_not_to_use=column_not_to_use,
                                               alpha=best_parameters_dict[kernel]["alpha"], 
                                               metrics = "mse", 
                                               features_to_scale = features_to_scale, scaling = scaling,
                                               print_results=print_results)
        elif kernel == "polynomial":
            tests['polynomial'] = TestTunedKernels(merged_df, drug_ids, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use,
                                                   alpha=best_parameters_dict[kernel]["alpha"], 
                                                   gamma= best_parameters_dict[kernel]["gamma"], 
                                                   degree=best_parameters_dict[kernel]["degree"], 
                                                   metrics = "mse", 
                                                   features_to_scale = features_to_scale, scaling = scaling,
                                                   print_results=print_results)
        else:
            tests[kernel] = TestTunedKernels(merged_df, drug_ids, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use,
                                             alpha=best_parameters_dict[kernel]["alpha"], 
                                             gamma= best_parameters_dict[kernel]["gamma"],
                                             coef0= best_parameters_dict[kernel]["coef0"],
                                             degree=1, metrics = "mse", 
                                             features_to_scale = features_to_scale, scaling = scaling,
                                             print_results=print_results)
    best_kernels = {}
    coef_names= ["coef_"+str(i) for i in range(1, number_coefficients+1)]
    compared_means = pd.DataFrame(index=coef_names, columns= kernels)
    for i in range(number_coefficients):
        test_kernels_comparison = pd.DataFrame(index=["mean", "min", "max"])
        for kernel in kernels:
            test_kernels_comparison[kernel] = tests[kernel][tests[kernel].columns[i]]
        
        compared_means.loc["coef_"+str(i+1), :] = test_kernels_comparison.loc["mean", :]
        print(test_kernels_comparison)
        best_kernels[i+1]= test_kernels_comparison.loc["mean", :].idxmin(axis=1)
        print("Coefficient: %d, best kernel: %s" % (i+1, best_kernels[i+1]))
    
    return best_kernels, compared_means

### Analytical Part

# **Data Preprocessing pipeline:**
#     1. filter drug_profiles data 
#     (123 - three stages of filtration, 23 - two stages of filtration):
#         - "results/filtered_drug_profiles_123" (less data)
#         - "results/filtered_drug_profiles_23" (more data)
#     2. add drug features to drug data
#     - "data/Drug_Features.csv" (original data)
#     - "results/drug_features_with_properties2.csv" (data with pubchem properties)
#     3. merged drug_profiles and drug_features
# **For goog comparison:**
#     filter merged data so that they have only drug with features 
#     <br>for both data frames (original drug features and with added pubchem features)

column_not_to_use = ["Unnamed: 0", "COSMIC_ID", "DRUG_ID", "Drug_Name", "Synonyms", "Target", "deriv_found", "PubChem_ID",
                     "elements", "inchi_key", "canonical_smiles", "inchi_string", "third_target", "first_target", "molecular_formula", "second_target", "Target_Pathway"]

param1 = ["param_" +str(i) for i in range(10)]
param2 = ["param" +str(i) for i in range(10)] 
norm_response  = ["norm_cells_"+str(i) for i in range(10)]

### 1. Finding optimal parameters for just drug profiles and cell lines

print("\n1. Finding optimal parameters for just drug profiles and cell lines\n")
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_description.csv').drop(["Drug_Name","Target_Pathway"], axis=1)

conc_columns= ["fd_num_"+str(i) for i in range(10)]
response_norm = ['norm_cells_'+str(i) for i in range(10)]

gr = df.groupby(["DRUG_ID"])["COSMIC_ID"].count()
drug_ids = list(gr[gr > 50].index)
print("Number of drugs for training:", len(drug_ids))

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, compared_means = TrainTestBestParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)
compared_means.to_csv(_FOLDER+"kernel_learning_1.csv")
print("\ncompared_means\n")
print(compared_means)
      

### 2. Finding optimal parameters for drug profiles, cell lines and drug description

print("\n2. Finding optimal parameters for drug profiles, cell lines and drug description\n")
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_description.csv')

# OHE and dumnies columns for Target_Pathway - 21 new columns
df = pd.concat([df, pd.get_dummies(df["Target_Pathway"])], axis=1).drop("Target_Pathway", axis=1)

conc_columns= ["fd_num_"+str(i) for i in range(10)]
response_norm = ['norm_cells_'+str(i) for i in range(10)]

gr = df.groupby(["DRUG_ID"])["COSMIC_ID"].count()
drug_ids = list(gr[gr > 50].index)
print("Number of drugs for training:", len(drug_ids))

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, compared_means = TrainTestBestParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)
compared_means.to_csv(_FOLDER+"kernel_learning_2.csv")

print("\ncompared_means\n")
print(compared_means)

### 3. Finding optimal parameters for drug profiles, cell lines and drug features

print("\n3. Finding optimal parameters for drug profiles, cell lines and drug features\n")
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_properties.csv')

gr = df.groupby(["DRUG_ID"])["COSMIC_ID"].count()
drug_ids = list(gr[gr > 50].index)
print("Number of drugs for training:", len(drug_ids))

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, compared_means = TrainTestBestParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)
compared_means.to_csv(_FOLDER+"kernel_learning_3.csv")
print("\ncompared_means\n")
print(compared_means)

### 4. Finding optimal parameters for drug profiles, cell lines and drug features with SCALING

print("\n4. Finding optimal parameters for drug profiles, cell lines and drug features with scaling\n")
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_properties.csv')

potential_columns_for_normalisation = []
for col in df.columns:
    if (df[col].nunique()>2) & (df[col].dtype != "O"):
        potential_columns_for_normalisation.append(col)

columns_for_normalisation = list(set(potential_columns_for_normalisation) - set(norm_response) - set(param1) - set(param2) -set(['Unnamed: 0', 'DRUG_ID', 'COSMIC_ID',]))
gr = df.groupby(["DRUG_ID"])["COSMIC_ID"].count()
drug_ids = list(gr[gr > 50].index)
print("Number of drugs for training:", len(drug_ids))

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(df, drug_ids, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, 
                         features_to_scale=columns_for_normalisation, scaling = True,
                         print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, compared_means = TrainTestBestParameters(df, drug_ids, 4, kernels = kernels_to_test, 
                                                       column_not_to_use=column_not_to_use, 
                                                       best_parameters_dict = results, 
                                                       features_to_scale=columns_for_normalisation, scaling = True,
                                                       print_results=True)
print("Best Kernels:", best_kernels)
compared_means.to_csv(_FOLDER+"kernel_learning_4.csv")
print("\ncompared_means\n")
print(compared_means)

# %% [markdown]
# ### Training and testing for all the data

# %%
import pandas as pd
import numpy as np
import time
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit
from scipy.optimize import leastsq
import scipy.optimize as opt
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import gc

from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import MinMaxScaler
import os
from data_preprocessing import FilteringCurves, ShowResponseCurves
from fitting_curves import FittingColumn, ShowResponseCurvesWithFitting, compute_r2_score

# from IPython.display import display
#_FOLDER = "results/"
_FOLDER = "/home/acq18mk/master/results/"

### Coding Part

def LeaveOneOutError(kernel_model, X, y, metrics = "mse"):
    errors = []
    splitter_loo = LeaveOneOut()
#     print(splitter_loo.get_n_splits(X))
    
    for train_index, test_index in splitter_loo.split(X):
        X_train_loo, X_test_loo = X[train_index, :], X[test_index,:]
        y_train_loo, y_test_loo = y[train_index], y[test_index]
        
        model = kernel_model.fit(X_train_loo, y_train_loo)
        if metrics == "mse":
            mse = mean_squared_error(y_test_loo, model.predict(X_test_loo))
            errors.append(mse)
        elif metrics == "mae":
            mae = mean_absolute_error(y_test_loo, model.predict(X_test_loo))
            errors.append(mae)
    
    return (sum(errors)/ len(errors)) 

# gamma for RBF, laplacian, polynomial, exponential chi2 and sigmoid kernels

def RunCrossValidation(df_train, number_coefficients, column_not_to_use =[], kernel='linear', param_tested = "alpha", 
                       param_tested_values = [], alpha=1, gamma=None, degree=3, coef0=1,features_to_scale=[], scaling=False, 
                      print_results=True):
    
    param1 = ["param_" +str(i) for i in range(10)]
    param2 = ["param" +str(i) for i in range(10)] 
    norm_response  = ["norm_cells_"+str(i) for i in range(10)]
    con_columns  = ["fd_num_"+str(i) for i in range(10)]
    not_X_columns = param1 + param2 + norm_response + con_columns+column_not_to_use
    X_columns = set(df_train.columns) - set(not_X_columns)
    
#     print("RunCrossValidation - string checking...")
#     string_col =[]
#     for col in X_columns:
#         if df_train[col].dtype=="object":
#             string_col.append(col)
#     if len(string_col)>0:
#         print(col)
#     else:
#         print("no string are found\n")
        
    
    df_errors = pd.DataFrame(index=["mse"])
    
    if scaling:
        train=df_train.copy()
        scaler = MinMaxScaler()
        train[columns_for_normalisation] = scaler.fit_transform(train[columns_for_normalisation])
#         print("CV1", "first_target" in )
        X_train = train[X_columns].values     
    else:
        X_train = df_train[X_columns].values
    
    for i in range(number_coefficients):
        #check whether each coefficient needs its own parameters
        if type(alpha)==dict:
            alpha_value = alpha[i+1]
        else:
            alpha_value = alpha
                
        if type(gamma)==dict:
            gamma_value = gamma[i+1]
        else:
            gamma_value = gamma
            
        if type(degree)==dict:
            degree_value = degree[i+1]
        else:
            degree_value = degree
                
        if type(coef0)==dict:
            coef0_value = coef0[i+1]
        else:
            coef0_value = coef0
            
        y_train = df_train["param_"+str(i+1)].values

        for param in param_tested_values:
            if param_tested == "alpha":
                kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=param, 
                                               gamma=gamma_value, 
                                               degree=degree_value, 
                                               coef0=coef0_value)
            elif param_tested == "gamma":
                kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value, 
                                               gamma=param, 
                                               degree=degree_value,
                                               coef0=coef0_value)
            elif param_tested == "degree":
                kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value, 
                                               gamma=gamma_value,
                                               degree=param, 
                                               coef0=coef0_value)
            elif param_tested == "coef0":
                kernel_model = KernelRidge(kernel=kernel, 
                                               alpha=alpha_value,  
                                               gamma=gamma_value,
                                               degree=degree_value,
                                               coef0=param)
            else:
                print("ERROR: Unknown parameters")
                
            # mse is more sensitive to different parameters choice
            mse = LeaveOneOutError(kernel_model, X_train, y_train, metrics="mse")
            df_errors.loc["mse", "mse_coef"+str(i+1)+"_"+str(param)] = mse

    best_values = {}
    for coef in range(number_coefficients):
        best_param = np.float32(df_errors.idxmin(axis=1)[0].split("_")[-1])
        best_values[coef+1] = best_param
        if print_results:
            print(df_results)
            print("Coefficient %d: ,  Best %s: %.5f" % (coef+1, param_tested, best_param))
        
    del df_errors
    print("%s kernel, best values for parameter: %s" % (kernel, param_tested))
    print(best_values)
    return best_values

def TestTunedKernels(df_train, df_test, number_coefficients, kernel, column_not_to_use =[], alpha=1, gamma=None, degree=3, coef0=1, 
                     metrics = "mse", features_to_scale=[], scaling=False, print_results=True):
    """Training and testing Kernels with the best found hyperparameters"""
    
    param1 = ["param_" +str(i) for i in range(10)]
    param2 = ["param" +str(i) for i in range(10)] 
    norm_response  = ["norm_cells_"+str(i) for i in range(10)]
    con_columns  = ["fd_num_"+str(i) for i in range(10)]

    not_X_columns = param1 + param2 + norm_response + con_columns+column_not_to_use
    X_columns = set(df_train.columns) - set(not_X_columns)
    print("Number of X_columns:", len(X_columns))
    
    df_errors_test = pd.DataFrame(index=["mse"])
    if scaling:
        train = df_train.copy()
        test = df_test.copy()
        scaler = MinMaxScaler()
        scaler.fit(train[columns_for_normalisation])
        train[columns_for_normalisation] = scaler.transform(train[columns_for_normalisation])
        X_train = train[X_columns].values  
        test[columns_for_normalisation] = scaler.transform(test[columns_for_normalisation])
        X_test = test[X_columns].values
    else:
        X_train = df_train[X_columns].values
        X_test = df_test[X_columns].values
    
    for i in range(number_coefficients):
        y_train = df_train["param_"+str(i+1)].values
        y_test = df_test["param_"+str(i+1)].values
            
        #check whether each coefficient needs its own parameters
        if type(alpha)==dict:
            alpha_value = alpha[i+1]
        else:
            alpha_value = alpha
                
        if type(gamma)==dict:
            gamma_value = gamma[i+1]
        else:
            gamma_value = gamma
            
        if type(degree)==dict:
            degree_value = degree[i+1]
        else:
            degree_value = degree
                
        if type(coef0)==dict:
            coef0_value = coef0[i+1]
        else:
            coef0_value = coef0
                
        kr_lin = KernelRidge(kernel = kernel, alpha = alpha_value, gamma=gamma_value, 
                                 degree=degree_value, coef0=coef0_value)
        kr_lin.fit(X_train, y_train)
        y_pred = kr_lin.predict(X_test)
                                
        # mse is more sensitive to different parameters choice
        if metrics == "mse":
            error = mean_squared_error(y_test, y_pred)
        elif metrics == "mae":
            error = mean_absolute_error(y_test, y_pred)
        else:
            print("ERROR: Unknown metrics")
        df_errors_test.loc["mse", kernel+" mse_coef"+str(i+1)] = error

    return df_errors_test


def TuneParameters(train, number_coefficients, kernels = [], column_not_to_use =[], param_tested = "alpha", 
                       param_tested_values = [], alpha=1, gamma=None, degree=3, coef0=1, features_to_scale=[], scaling=False, 
                      print_results=True):
    results = {}
    for kernel in kernels:
        start_time = time.time()
        if kernel == "linear":
            best_alpha = RunCrossValidation(train, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use, 
                                            param_tested = "alpha", param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500],
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)
            
            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            
        elif kernel == "polynomial":
            start_time = time.time()
            best_gamma = RunCrossValidation(train, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "gamma", 
                                            param_tested_values = [0.00001, 0.0001, 0.01, 0.1, 1], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            best_degree = RunCrossValidation(train, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "degree", 
                                             gamma= best_gamma, param_tested_values = [1,2,3,4,5], 
                                             features_to_scale = features_to_scale, scaling = scaling,
                                             print_results=print_results)

            best_alpha = RunCrossValidation(train, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use, param_tested = "alpha", 
                                            gamma= best_gamma, degree = best_degree,
                                            param_tested_values = [0.001, 0.01, 0.1, 1, 5, 7], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)            
            
            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            results[kernel]["gamma"] = best_gamma
            results[kernel]["degree"] = best_degree
            
        else: 
            start_time = time.time()
            best_gamma = RunCrossValidation(train, number_coefficients, kernel = kernel, column_not_to_use=column_not_to_use, param_tested = "gamma", 
                                            param_tested_values = [0.00001, 0.0001, 0.01, 0.1, 0.5, 1], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            
            best_alpha = RunCrossValidation(train, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use, param_tested = "alpha", 
                                            param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)
            
            best_coef0 = RunCrossValidation(train, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use, gamma= best_gamma, 
                                            param_tested = "coef0", alpha=best_alpha,
                                            param_tested_values = [-0.1, 0, 0.1, 0.5, 1,  5, 10], 
                                            features_to_scale = features_to_scale, scaling = scaling,
                                            print_results=print_results)

            print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
            results[kernel]={}
            results[kernel]["alpha"] = best_alpha
            results[kernel]["gamma"] = best_gamma
            results[kernel]["coef0"] = best_coef0
            
    return  results

def TrainTestBestParameters(train, test, number_coefficients, kernels =[], column_not_to_use =[], best_parameters_dict={}, 
                     metrics = "mse", features_to_scale=[], scaling=False, print_results=True):
    
    df_results = pd.DataFrame()
    for kernel in kernels:
        if kernel == "linear":
            test_results = TestTunedKernels(train, test, number_coefficients, kernel='linear', column_not_to_use=column_not_to_use,
                                               alpha=best_parameters_dict[kernel]["alpha"], 
                                               metrics = "mse", 
                                               features_to_scale = features_to_scale, scaling = scaling,
                                               print_results=print_results)
            df_results = pd.concat([df_results, test_results], axis=1)
            
        elif kernel == "polynomial":
            test_results = TestTunedKernels(train, test, number_coefficients, kernel='polynomial', column_not_to_use=column_not_to_use,
                                                   alpha=best_parameters_dict[kernel]["alpha"], 
                                                   gamma= best_parameters_dict[kernel]["gamma"], 
                                                   degree=best_parameters_dict[kernel]["degree"], 
                                                   metrics = "mse", 
                                                   features_to_scale = features_to_scale, scaling = scaling,
                                                   print_results=print_results)
            df_results = pd.concat([df_results, test_results], axis=1)
            
        else:
            test_results = TestTunedKernels(train, test, number_coefficients, kernel=kernel, column_not_to_use=column_not_to_use,
                                             alpha=best_parameters_dict[kernel]["alpha"], 
                                             gamma= best_parameters_dict[kernel]["gamma"],
                                             coef0= best_parameters_dict[kernel]["coef0"],
                                             degree=1, metrics = "mse", 
                                             features_to_scale = features_to_scale, scaling = scaling,
                                             print_results=print_results)
            df_results = pd.concat([df_results, test_results], axis=1)
    
#     print("TrainTestBestParameters",df_results)
    best_kernels = {}
    for coef in range(1, number_coefficients+1):
        columns_names = [kernel+" mse_coef"+str(coef)]
        best_kernels[coef] ={}
        best_kernels[coef]["kernel"] = df_results[columns_names].idxmin(axis=1)[0].split(" ")[0]
        best_kernels[coef]["mse"] = df_results[columns_names].min(axis=1)[0]
    
    return best_kernels, df_results

### Analytical Part

# **Data Preprocessing pipeline:**
#     1. filter drug_profiles data 
#     (123 - three stages of filtration, 23 - two stages of filtration):
#         - "results/filtered_drug_profiles_123" (less data)
#         - "results/filtered_drug_profiles_23" (more data)
#     2. add drug features to drug data
#     - "data/Drug_Features.csv" (original data)
#     - "results/drug_features_with_properties2.csv" (data with pubchem properties)
#     3. merged drug_profiles and drug_features
# **For goog comparison:**
#     filter merged data so that they have only drug with features 
#     <br>for both data frames (original drug features and with added pubchem features)

column_not_to_use = ["Unnamed: 0", "Unnamed: 0.1","COSMIC_ID", "DRUG_ID", "Drug_Name", "Synonyms", "Target", "deriv_found", "PubChem_ID",
                     "elements", "inchi_key", "canonical_smiles", "inchi_string", "third_target", "first_target", "molecular_formula", "second_target", "Target_Pathway"]

param1 = ["param_" +str(i) for i in range(10)]
param2 = ["param" +str(i) for i in range(10)] 
norm_response  = ["norm_cells_"+str(i) for i in range(10)]

print("Dealing with ready train and test data!!!")

### 1. Finding optimal parameters for just drug profiles and cell lines

print("\n1. Finding optimal parameters for just drug profiles and cell lines\n")

train = pd.read_csv(_FOLDER+"train08_merged_fitted_sigmoid4_123_with_drugs_description.csv")
test = pd.read_csv(_FOLDER+"test02_merged_fitted_sigmoid4_123_with_drugs_description.csv")

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, df_results = TrainTestBestParameters(train, test, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)

print("\nAll results\n")
print(df_results)
df_results.to_csv(_FOLDER+"kernel_learning_1_2.csv")
      

### 2. Finding optimal parameters for drug profiles, cell lines and drug description

print("\n2. Finding optimal parameters for drug profiles, cell lines and drug description\n")

train = pd.read_csv(_FOLDER+"train08_merged_fitted_sigmoid4_123_with_drugs_description.csv")
test = pd.read_csv(_FOLDER+"test02_merged_fitted_sigmoid4_123_with_drugs_description.csv")

# OHE and dumnies columns for Target_Pathway - 21 new columns
df = pd.concat([df, pd.get_dummies(df["Target_Pathway"])], axis=1).drop("Target_Pathway", axis=1)

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, df_results = TrainTestBestParameters(train, test, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)

print("\nAll results\n")
print(df_results)
df_results.to_csv(_FOLDER+"kernel_learning_2_2.csv")

### 3. Finding optimal parameters for drug profiles, cell lines and drug features

print("\n3. Finding optimal parameters for drug profiles, cell lines and drug features\n")

train = pd.read_csv(_FOLDER+"train08_merged_fitted_sigmoid4_123_with_drugs_properties.csv")
test = pd.read_csv(_FOLDER+ "test02_merged_fitted_sigmoid4_123_with_drugs_properties.csv")

kernels_to_test = ["linear", "sigmoid", "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, print_results=False)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, df_results = TrainTestBestParameters(train, test, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, best_parameters_dict = results, print_results=True)
print("Best Kernels:", best_kernels)

print("\nAll results\n")
print(df_results)
df_results.to_csv(_FOLDER+"kernel_learning_3_2.csv")

### 4. Finding optimal parameters for drug profiles, cell lines and drug features with SCALING

print("\n4. Finding optimal parameters for drug profiles, cell lines and drug features with scaling\n")

train_set = pd.read_csv(_FOLDER+"train08_merged_fitted_sigmoid4_123_with_drugs_properties.csv")
test_set = pd.read_csv(_FOLDER+ "test02_merged_fitted_sigmoid4_123_with_drugs_properties.csv")

potential_columns_for_normalisation = []
for col in train_set.columns:
    if (train_set[col].nunique()>2) & (train_set[col].dtype != "O"):
        potential_columns_for_normalisation.append(col)
        
param1 = ["param_" +str(i) for i in range(10)]
param2 = ["param" +str(i) for i in range(10)] 
conc_columns= ["fd_num_"+str(i) for i in range(10)]
norm_response  = ["norm_cells_"+str(i) for i in range(10)]
column_not_to_use = ["Unnamed: 0", "Unnamed: 0.1","COSMIC_ID", "DRUG_ID", "Drug_Name", "Synonyms", "Target", "deriv_found", "PubChem_ID",
                     "elements", "inchi_key", "canonical_smiles", "inchi_string", "third_target", "first_target", "molecular_formula", "second_target", "Target_Pathway"]


columns_for_normalisation = list(set(potential_columns_for_normalisation) - set(norm_response) - set(param1) - set(param2) -set(['Unnamed: 0', 'DRUG_ID', 'COSMIC_ID',]))

kernels_to_test_set = ["linear", "sigmoid"]#, "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(train_set, number_coefficients=4, kernels=kernels_to_test_set, 
                         column_not_to_use=column_not_to_use,  
                         alpha=1, gamma=None, degree=3, coef0=1, 
                         features_to_scale=columns_for_normalisation, 
                         scaling=True, print_results=True)

print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, df_results = TrainTestBestParameters(train, test, 4, kernels = kernels_to_test, 
                                                   column_not_to_use=column_not_to_use, 
                                                   best_parameters_dict = results, 
                                                   features_to_scale=columns_for_normalisation, scaling=True,
                                                   print_results=True)
print("Best Kernels:", best_kernels)

print("\nAll results\n")
print(df_results)
df_results.to_csv(_FOLDER+"kernel_learning_4_2.csv")

# %%
# Out:
# third_target
# first_target
# molecular_formula
# second_target
# Drug_Name

# %%
### 4. Finding optimal parameters for drug profiles, cell lines and drug features with SCALING

print("\n4. Finding optimal parameters for drug profiles, cell lines and drug features with scaling\n")

train = pd.read_csv(_FOLDER+"train08_merged_fitted_sigmoid4_123_with_drugs_properties.csv")
test = pd.read_csv(_FOLDER+ "test02_merged_fitted_sigmoid4_123_with_drugs_properties.csv")
# Out:
# 4. Finding optimal parameters for drug profiles, cell lines and drug features with scaling

# %%
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_properties.csv')

potential_columns_for_normalisation = []
for col in df.columns:
    if (df[col].nunique()>2) & (df[col].dtype != "O"):
        potential_columns_for_normalisation.append(col)

columns_for_normalisation = list(set(potential_columns_for_normalisation) - set(norm_response) - set(param1) - set(param2) -set(['Unnamed: 0', 'DRUG_ID', 'COSMIC_ID',]))

print(len(columns_for_normalisation))
kernels_to_test = ["linear", "sigmoid"]#, "rbf", "polynomial", "additive_chi2", "laplacian"]
results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use, 
                         features_to_scale=columns_for_normalisation, scaling = True,
                         print_results=False)
# Out:
# 13
# The string columns: loss:cnaPANCAN397
# The string columns: NCOR2_mut
# The string columns: chr19:58458686-58459219(ZNF256)_HypMET
# The string columns: XRN1_mut
# The string columns: loss:cnaPANCAN148
# The string columns: loss:cnaPANCAN254
# The string columns: chr16:3355020-3356012(TIGD7)_HypMET
# The string columns: chr4:165878036-165878446(C4orf39, TRIM61)_HypMET
# The string columns: chr10:102891010-102891794(TLX1NB, TLX1)_HypMET
# The string columns: gain:cnaPANCAN348
# The string columns: loss:cnaPANCAN329 (ZNF750)
# The string columns: STK4_mut
# The string columns: loss:cnaPANCAN361
# The string columns: loss:cnaPANCAN225
# The string columns: chr5:63461448-63462106()_HypMET
# The string columns: TET2_mut
# The string columns: gain:cnaPANCAN27 (GATA3,KLF6,LARP4B,VIM)
# The string columns: chr7:119912840-119913883(KCND2)_HypMET
# The string columns: TNPO1_mut
# The string columns: ASXL1_mut
# The string columns: BNC2_mut
# The string columns: NR4A2_mut
# The string columns: MED24_mut
# The string columns: chr4:1005930-1006282(FGFRL1)_HypMET
# The string columns: gain:cnaPANCAN268
# The string columns: chr5:35617855-35618339(SPEF2)_HypMET
# The string columns: loss:cnaPANCAN298
# The string columns: ANK3_mut
# The string columns: chr14:70345943-70346527(SMOC1)_HypMET
# The string columns: chr19:49315545-49315765(BCAT2)_HypMET
# The string columns: U2AF1_mut
# The string columns: loss:cnaPANCAN316
# The string columns: gain:cnaPANCAN279
# The string columns: chr14:48143433-48145589(MDGA2)_HypMET
# The string columns: SMAD2_mut
# The string columns: chr7:62858468-62858826(LOC100287834)_HypMET
# The string columns: chr3:56502611-56502815(ERC2)_HypMET
# The string columns: chr20:62433937-62434203(ZBTB46)_HypMET
# The string columns: loss:cnaPANCAN174
# The string columns: chr18:47087879-47088528(LIPG)_HypMET
# The string columns: ERBB2IP_mut
# The string columns: loss:cnaPANCAN399
# The string columns: JNK and p38 signaling
# The string columns: chr12:132690339-132690571(GALNT9)_HypMET
# The string columns: NPM1_mut
# The string columns: chr11:75378416-75379882(MAP6)_HypMET
# The string columns: S
# The string columns: ARFGEF2_mut
# The string columns: loss:cnaPANCAN357 (ACVR2A)
# The string columns: CDKN2A_mut
# The string columns: gain:cnaPANCAN344 (MYCN)
# The string columns: chr18:77905297-77905566(LOC100130522)_HypMET
# The string columns: loss:cnaPANCAN417
# The string columns: loss:cnaPANCAN66
# The string columns: gain:cnaPANCAN240
# The string columns: loss:cnaPANCAN257
# The string columns: chr14:59930634-59932251()_HypMET
# The string columns: chr20:61560433-61560954(DIDO1)_HypMET
# The string columns: chr15:64679907-64680233(TRIP4)_HypMET
# The string columns: chr19:15342626-15343181(EPHX3)_HypMET
# The string columns: loss:cnaPANCAN53
# The string columns: gain:cnaPANCAN331
# The string columns: chr7:143582125-143582610(FAM115A)_HypMET
# The string columns: MYH14_mut
# The string columns: loss:cnaPANCAN68
# The string columns: gain:cnaPANCAN362 (CRNKL1,FOXA2)
# The string columns: loss:cnaPANCAN377
# The string columns: CTCF_mut
# The string columns: loss:cnaPANCAN150 (PTGS1)
# The string columns: formal_charge
# The string columns: Chromatin other
# The string columns: gain:cnaPANCAN345
# The string columns: chr18:5543437-5544241(EPB41L3)_HypMET
# The string columns: gain:cnaPANCAN18
# The string columns: EIF4A2_mut
# The string columns: loss:cnaPANCAN38
# The string columns: MNDA_mut
# The string columns: gain:cnaPANCAN269 (MACF1)
# The string columns: chr19:50706482-50707196(MYH14)_HypMET
# The string columns: loss:cnaPANCAN154
# The string columns: ARID5B_mut
# The string columns: Cell cycle
# The string columns: ABCB1_mut
# The string columns: ADCY1_mut
# The string columns: gain:cnaPANCAN382 (FLT3,WASF3)
# The string columns: I
# The string columns: chr20:47443734-47445181(PREX1)_HypMET
# The string columns: LRP6_mut
# The string columns: chr2:21022564-21022934(C2orf43)_HypMET
# The string columns: chr9:35791584-35791924(NPR2)_HypMET
# The string columns: loss:cnaPANCAN262 (FOXP1)
# The string columns: chr7:99678768-99679702(ZNF3)_HypMET
# The string columns: ARID1A_mut
# The string columns: chr12:50297580-50297988(FAIM2)_HypMET
# The string columns: loss:cnaPANCAN291 (JAK1)
# The string columns: chr13:96296143-96297059(DZIP1)_HypMET
# The string columns: chr5:179243545-179244453(SQSTM1)_HypMET
# The string columns: EWSR1-X_mut
# The string columns: loss:cnaPANCAN334
# The string columns: ARFGEF1_mut
# The string columns: loss:cnaPANCAN77 (CASP1)
# The string columns: RTK signaling
# The string columns: loss:cnaPANCAN251
# The string columns: WHSC1_mut
# The string columns: chr22:19746924-19747141(TBX1)_HypMET
# The string columns: chr12:39299248-39299629(CPNE8)_HypMET
# The string columns: KRAS_mut
# The string columns: TBX3_mut
# The string columns: chr13:27131568-27132677()_HypMET
# The string columns: surface_area
# The string columns: loss:cnaPANCAN11
# The string columns: gain:cnaPANCAN242 (PIK3CB)
# The string columns: RASA2_mut
# The string columns: chr19:41106058-41106415(LTBP4)_HypMET
# The string columns: loss:cnaPANCAN401
# The string columns: N
# The string columns: PIK3C2B_mut
# The string columns: PIK3CB_mut
# The string columns: RUNX1-RUNX1T1_mut
# The string columns: chr13:43566074-43566508(EPSTI1)_HypMET
# The string columns: loss:cnaPANCAN47
# The string columns: FAF1_mut
# The string columns: loss:cnaPANCAN289 (CDKN2C,FAF1)
# The string columns: loss:cnaPANCAN195
# The string columns: ASXL2_mut
# The string columns: gain:cnaPANCAN347
# The string columns: SMAD4_mut
# The string columns: chr1:153935781-153936276(SLC39A1)_HypMET
# The string columns: loss:cnaPANCAN358
# The string columns: ASPM_mut
# The string columns: USP6_mut
# The string columns: EWRS1-ERG_mut
# The string columns: SOX9_mut
# The string columns: loss:cnaPANCAN100
# The string columns: chr19:42501261-42501486(ATP1A3)_HypMET
# The string columns: chr13:36052553-36053119(MIR548F5, NBEA, MAB21L1)_HypMET
# The string columns: MYC_mut
# The string columns: GATA3_mut
# The string columns: chr10:135043221-135044560(UTF1)_HypMET
# The string columns: PTCH1_mut
# The string columns: gain:cnaPANCAN213 (MCM3)
# The string columns: loss:cnaPANCAN219
# The string columns: loss:cnaPANCAN194 (FGFR3)
# The string columns: loss:cnaPANCAN386
# The string columns: chr20:30310503-30310707(BCL2L1)_HypMET
# The string columns: chr18:10454453-10455268(APCDD1)_HypMET
# The string columns: loss:cnaPANCAN160
# The string columns: chr2:183731819-183732093(FRZB)_HypMET
# The string columns: NOTCH2_mut
# The string columns: MLL_mut
# The string columns: loss:cnaPANCAN63
# The string columns: chr12:104697348-104697984(EID3, TXNRD1)_HypMET
# The string columns: Mitosis
# The string columns: chr8:95652455-95652873(ESRP1)_HypMET
# The string columns: gain:cnaPANCAN394 (GNG2,SOS2)
# The string columns: loss:cnaPANCAN98
# The string columns: loss:cnaPANCAN359 (CUL3)
# The string columns: gain:cnaPANCAN177 (IL7R)
# The string columns: chr7:27225050-27225629(HOXA11AS, HOXA11)_HypMET
# The string columns: FTSJD1_mut
# The string columns: chr3:194406440-194409045(FAM43A)_HypMET
# The string columns: chr6:26045644-26046033()_HypMET
# The string columns: chr3:101568107-101569046(NFKBIZ)_HypMET
# The string columns: chr7:150065169-150066351(REPIN1)_HypMET
# The string columns: loss:cnaPANCAN201
# The string columns: loss:cnaPANCAN188
# The string columns: NRAS_mut
# The string columns: chr4:57371582-57372022(ARL9)_HypMET
# The string columns: chr8:144659745-144660635(NAPRT1)_HypMET
# The string columns: loss:cnaPANCAN10 (CIC)
# The string columns: ELF1_mut
# The string columns: chr1:180881316-180882592(KIAA1614)_HypMET
# The string columns: LRPPRC_mut
# The string columns: Br
# The string columns: KDM5C_mut
# The string columns: RAD21_mut
# The string columns: loss:cnaPANCAN43
# The string columns: EPHA4_mut
# The string columns: gain:cnaPANCAN59 (CCND1,CTTN)
# The string columns: chr9:104248247-104249501(C9orf125)_HypMET
# The string columns: chr4:103940668-103940951(NHEDC1)_HypMET
# The string columns: loss:cnaPANCAN25
# The string columns: chr1:60539315-60539540(C1orf87)_HypMET
# The string columns: chr17:46655215-46655604(HOXB4)_HypMET
# The string columns: gain:cnaPANCAN351 (NFE2L2)
# The string columns: PLCG1_mut
# The string columns: KAT6B_mut
# The string columns: GNA11_mut
# The string columns: chr12:3862068-3862606(EFCAB4B)_HypMET
# The string columns: loss:cnaPANCAN199
# The string columns: chr19:58011124-58011743(ZNF773)_HypMET
# The string columns: chr12:49782965-49783193(SPATS2)_HypMET
# The string columns: chr13:79175610-79177985(POU4F1)_HypMET
# The string columns: chr19:44763978-44764312(ZNF233)_HypMET
# The string columns: chr3:49314437-49314815(C3orf62)_HypMET
# The string columns: chr9:86571047-86572027(C9orf64)_HypMET
# The string columns: loss:cnaPANCAN118 (ZFHX3)
# The string columns: chr22:20790638-20792665(SCARF2)_HypMET
# The string columns: gain:cnaPANCAN128
# The string columns: gain:cnaPANCAN392 (CHD8)
# The string columns: Chromatin histone acetylation
# The string columns: FLT3_mut
# The string columns: loss:cnaPANCAN22
# The string columns: gain:cnaPANCAN122 (AHR,HDAC9)
# The string columns: chr10:48438411-48439320(GDF10)_HypMET
# The string columns: chr8:11058624-11058844(XKR6)_HypMET
# The string columns: loss:cnaPANCAN373
# The string columns: loss:cnaPANCAN413
# The string columns: loss:cnaPANCAN149
# The string columns: chr19:37957726-37958390(ZNF569)_HypMET
# The string columns: gain:cnaPANCAN393 (FOXA1,NKX2-1,PSMA6)
# The string columns: KIT_mut
# The string columns: C15orf55_mut
# The string columns: GNAS_mut
# The string columns: chr5:59189046-59189894(PDE4D)_HypMET
# The string columns: loss:cnaPANCAN389 (RB1)
# The string columns: ARHGAP26_mut
# The string columns: chr19:53496732-53497028()_HypMET
# The string columns: AKT1_mut
# The string columns: gain:cnaPANCAN303
# The string columns: loss:cnaPANCAN385 (PABPC3,SACS,ZMYM2)
# The string columns: loss:cnaPANCAN34
# The string columns: loss:cnaPANCAN418
# The string columns: covalent_unit_count
# The string columns: loss:cnaPANCAN92
# The string columns: loss:cnaPANCAN147
# The string columns: chr11:113185332-113185663(TTC12)_HypMET
# The string columns: chr3:99594969-99595215(C3orf26, FILIP1L, MIR548G)_HypMET
# The string columns: ATM_mut
# The string columns: loss:cnaPANCAN314
# The string columns: loss:cnaPANCAN78 (CASP1)
# The string columns: chr1:214161197-214161415(PROX1)_HypMET
# The string columns: loss:cnaPANCAN356 (ERCC3)
# The string columns: chr15:40544352-40545512(PAK6, C15orf56)_HypMET
# The string columns: HGF_mut
# The string columns: LARP4B_mut
# The string columns: gain:cnaPANCAN130 (RHEB)
# The string columns: loss:cnaPANCAN297
# The string columns: chr1:1167001-1168985(SDF4, B3GALT6)_HypMET
# The string columns: chr5:115912001-115912384(SEMA6A)_HypMET
# The string columns: gain:cnaPANCAN106
# The string columns: loss:cnaPANCAN311
# The string columns: gain:cnaPANCAN333 (F8,HCFC1,RPL10)
# The string columns: loss:cnaPANCAN381 (ARFGAP3)
# The string columns: chr3:238391-240140(CHL1)_HypMET
# The string columns: loss:cnaPANCAN21
# The string columns: loss:cnaPANCAN223
# The string columns: chr11:46402624-46404139(MDK)_HypMET
# The string columns: DDX5_mut
# The string columns: chr6:85472702-85474132(TBX18)_HypMET
# The string columns: loss:cnaPANCAN287
# The string columns: chr19:37095680-37096589(ZNF529, ZNF382)_HypMET
# The string columns: loss:cnaPANCAN51
# The string columns: EPHA2_mut
# The string columns: TCF4_mut
# The string columns: loss:cnaPANCAN7 (SMARCA4)
# The string columns: gain:cnaPANCAN270 (JUN)
# The string columns: loss:cnaPANCAN99 (SOX17)
# The string columns: O
# The string columns: chr10:102756834-102759798(LZTS2)_HypMET
# The string columns: chr17:66255192-66255556(ARSG)_HypMET
# The string columns: chr3:50604905-50605359(C3orf18)_HypMET
# The string columns: chr4:83933332-83934370(LIN54)_HypMET
# The string columns: chr16:68676450-68676843(CDH3)_HypMET
# The string columns: loss:cnaPANCAN162
# The string columns: chr12:124246524-124247254(DNAH10)_HypMET
# The string columns: loss:cnaPANCAN196
# The string columns: chr7:95025559-95026122(PON3)_HypMET
# The string columns: loss:cnaPANCAN343
# The string columns: chr5:5139441-5140941(ADAMTS16)_HypMET
# The string columns: loss:cnaPANCAN119
# The string columns: loss:cnaPANCAN159
# The string columns: chr1:53308294-53309262(ZYG11A)_HypMET
# The string columns: chr5:178322713-178323538(ZFP2)_HypMET
# The string columns: gain:cnaPANCAN332
# The string columns: HLA-B_mut
# The string columns: EGFR signaling
# The string columns: DHX9_mut
# The string columns: IDH2_mut
# The string columns: BAZ2B_mut
# The string columns: chr19:37406931-37407463(ZNF829)_HypMET
# The string columns: STAG2_mut
# The string columns: loss:cnaPANCAN67
# The string columns: chr10:135123238-135123448(ZNF511, TUBGCP2)_HypMET
# The string columns: gain:cnaPANCAN247
# The string columns: gain:cnaPANCAN300
# The string columns: loss:cnaPANCAN205
# The string columns: chr11:119293320-119293943(THY1)_HypMET
# The string columns: loss:cnaPANCAN220 (HIST1H3B)
# The string columns: BRCA2_mut
# The string columns: ARID4A_mut
# The string columns: gain:cnaPANCAN84 (FGFR1,WHSC1L1)
# The string columns: chr19:57078365-57079301(ZNF470)_HypMET
# The string columns: gain:cnaPANCAN364 (STK4)
# The string columns: loss:cnaPANCAN227
# The string columns: loss:cnaPANCAN305
# The string columns: loss:cnaPANCAN104
# The string columns: APC_mut
# The string columns: CSDE1_mut
# The string columns: loss:cnaPANCAN296
# The string columns: loss:cnaPANCAN253
# The string columns: TAF1_mut
# The string columns: gain:cnaPANCAN123
# The string columns: chr10:44879714-44882391(CXCL12)_HypMET
# The string columns: Pt
# The string columns: loss:cnaPANCAN44 (BMPR1A,FAS,PTEN)
# The string columns: chr10:93392667-93393147(PPP1R3C)_HypMET
# The string columns: gain:cnaPANCAN277 (DHX9)
# The string columns: ATRX_mut
# The string columns: RTN4_mut
# The string columns: B
# The string columns: RB1_mut
# The string columns: gain:cnaPANCAN19
# The string columns: loss:cnaPANCAN76
# The string columns: chr19:51069359-51069600(LRRC4B)_HypMET
# The string columns: UPF3B_mut
# The string columns: chr8:116660432-116660747(TRPS1)_HypMET
# The string columns: loss:cnaPANCAN113
# The string columns: loss:cnaPANCAN416
# The string columns: chr6:105584148-105585621(BVES)_HypMET
# The string columns: chr3:181430141-181431076(SOX2OT, SOX2)_HypMET
# The string columns: gain:cnaPANCAN249
# The string columns: loss:cnaPANCAN167
# The string columns: gain:cnaPANCAN278 (MDM4,PIK3C2B,ZC3H11A)
# The string columns: AQR_mut
# The string columns: gain:cnaPANCAN109 (MMP2)
# The string columns: HLA-A_mut
# The string columns: loss:cnaPANCAN203
# The string columns: chr19:18118741-18119553(ARRDC2)_HypMET
# The string columns: loss:cnaPANCAN372
# The string columns: chr13:28544524-28544890(CDX2)_HypMET
# The string columns: loss:cnaPANCAN95
# The string columns: chr6:26184036-26184336()_HypMET
# The string columns: IDH1_mut
# The string columns: chr19:57831599-57832250(ZNF543)_HypMET
# The string columns: chr6:26044203-26044469(HIST1H2BB, HIST1H3C)_HypMET
# The string columns: chr15:45315201-45315543(SORD)_HypMET
# The string columns: gain:cnaPANCAN1 (CCNE1)
# The string columns: CYLD_mut
# The string columns: FBXW7_mut
# The string columns: ARHGEF6_mut
# The string columns: loss:cnaPANCAN70
# The string columns: chr2:216877899-216878352(MREG)_HypMET
# The string columns: loss:cnaPANCAN368
# The string columns: FAT2_mut
# The string columns: chr21:47602431-47602740(C21orf56)_HypMET
# The string columns: loss:cnaPANCAN341
# The string columns: bond_stereo_count
# The string columns: PML-RARA_mut
# The string columns: loss:cnaPANCAN182
# The string columns: loss:cnaPANCAN185
# The string columns: loss:cnaPANCAN72
# The string columns: chr16:56659107-56659660(MT1E)_HypMET
# The string columns: MCM8_mut
# The string columns: chr16:67464388-67465462(HSD11B2)_HypMET
# The string columns: chr19:58446336-58446800(ZNF418)_HypMET
# The string columns: gain:cnaPANCAN237
# The string columns: chr8:41507516-41507868(NKX6-3)_HypMET
# The string columns: loss:cnaPANCAN369
# The string columns: loss:cnaPANCAN14
# The string columns: loss:cnaPANCAN260
# The string columns: gain:cnaPANCAN374
# The string columns: chr6:110679417-110679833(C6orf186)_HypMET
# The string columns: gain:cnaPANCAN61
# The string columns: chr1:248020330-248021252()_HypMET
# The string columns: chr13:25670041-25670531(PABPC3)_HypMET
# The string columns: ATR_mut
# The string columns: loss:cnaPANCAN380
# The string columns: chr6:291948-292839(DUSP22)_HypMET
# The string columns: loss:cnaPANCAN97
# The string columns: chr1:2064628-2064855(PRKCZ)_HypMET
# The string columns: chr17:40274523-40275360(HSPB9, KAT2A)_HypMET
# The string columns: loss:cnaPANCAN323
# The string columns: loss:cnaPANCAN180
# The string columns: chr19:21265164-21265433(ZNF714)_HypMET
# The string columns: loss:cnaPANCAN218
# The string columns: loss:cnaPANCAN170
# The string columns: gain:cnaPANCAN280 (ARID4B,FH)
# The string columns: chr22:24384134-24384405(GSTT1)_HypMET
# The string columns: chr3:53032813-53033116(SFMBT1)_HypMET
# The string columns: chr18:32847284-32848130(ZNF397OS)_HypMET
# The string columns: ACACA_mut
# The string columns: chr19:37157632-37158119(ZNF461)_HypMET
# The string columns: chr22:39853323-39854065(MGAT3)_HypMET
# The string columns: loss:cnaPANCAN36 (RET)
# The string columns: defined_atom_stereo_count
# The string columns: gain:cnaPANCAN349 (INPP4A)
# The string columns: MECOM_mut
# The string columns: loss:cnaPANCAN336
# The string columns: ARID2_mut
# The string columns: loss:cnaPANCAN339 (ATRX)
# The string columns: DDX3X_mut
# The string columns: CDKN1B_mut
# The string columns: TMPRSS2-ERG_mut
# The string columns: chr10:64133789-64134420(ZNF365)_HypMET
# The string columns: chr11:22850765-22851367(SVIP)_HypMET
# The string columns: loss:cnaPANCAN307 (CHD3,GPS2,TP53)
# The string columns: gain:cnaPANCAN125
# The string columns: RPL5_mut
# The string columns: gain:cnaPANCAN165 (CDK4)
# The string columns: chr22:20459267-20461473()_HypMET
# The string columns: chr2:190539026-190539533(ANKAR)_HypMET
# The string columns: MTOR_mut
# The string columns: loss:cnaPANCAN250 (SRGAP3)
# The string columns: gain:cnaPANCAN89 (RAD21)
# The string columns: PGR_mut
# The string columns: RUNX1_mut
# The string columns: Other
# The string columns: loss:cnaPANCAN407
# The string columns: ZFP36L1_mut
# The string columns: loss:cnaPANCAN181
# The string columns: gain:cnaPANCAN273
# The string columns: MLL-AFF1_mut
# The string columns: chr1:10755226-10755521(CASZ1)_HypMET
# The string columns: gain:cnaPANCAN176 (CCT5,TERT,TRIO)
# The string columns: chr12:103889148-103889843(C12orf42)_HypMET
# The string columns: loss:cnaPANCAN64
# The string columns: chr1:16085147-16085862(FBLIM1)_HypMET
# The string columns: PABPC3_mut
# The string columns: loss:cnaPANCAN320
# The string columns: KEAP1_mut
# The string columns: B2M_mut
# The string columns: loss:cnaPANCAN405
# The string columns: Genome integrity
# The string columns: chr19:58125530-58125902()_HypMET
# The string columns: gain:cnaPANCAN301 (CDK12,ERBB2,MED24)
# The string columns: loss:cnaPANCAN96
# The string columns: loss:cnaPANCAN23 (SMAD4)
# The string columns: loss:cnaPANCAN111
# The string columns: CEP290_mut
# The string columns: chr10:38645112-38645513(HSD17B7P2)_HypMET
# The string columns: chr17:79818230-79819299(P4HB)_HypMET
# The string columns: PPP2R1A_mut
# The string columns: ARID4B_mut
# The string columns: VHL_mut
# The string columns: P
# The string columns: chr1:111505881-111507007(C1orf103)_HypMET
# The string columns: loss:cnaPANCAN8
# The string columns: loss:cnaPANCAN9
# The string columns: loss:cnaPANCAN114 (CIITA)
# The string columns: loss:cnaPANCAN210 (FAT1,IRF2)
# The string columns: chr8:67940691-67940997(LRRC67)_HypMET
# The string columns: chr22:46440393-46441019()_HypMET
# The string columns: chr6:3227025-3229688(TUBB2B)_HypMET
# The string columns: MSR1_mut
# The string columns: loss:cnaPANCAN229
# The string columns: loss:cnaPANCAN259
# The string columns: SETD2_mut
# The string columns: chr1:146649622-146649852(PDIA3P)_HypMET
# The string columns: chr6:105627406-105627830(POPDC3)_HypMET
# The string columns: ZC3H11A_mut
# The string columns: chr22:24372912-24373725(LOC391322)_HypMET
# The string columns: loss:cnaPANCAN48
# The string columns: gain:cnaPANCAN142
# The string columns: loss:cnaPANCAN41
# The string columns: gain:cnaPANCAN367 (ARFGAP1,GNAS)
# The string columns: gain:cnaPANCAN383
# The string columns: loss:cnaPANCAN135
# The string columns: chr2:173940414-173941271(ZAK)_HypMET
# The string columns: chr5:140305712-140307193(PCDHA7, PCDHA12, PCDHA6, PCDHAC1, PCDHA10, PCDHA4, PCDHA11, PCDHA8, PCDHA1, PCDHA2, PCDHA9, PCDHA13, PCDHA5, PCDHA3)_HypMET
# The string columns: loss:cnaPANCAN52
# The string columns: NFE2L2_mut
# The string columns: loss:cnaPANCAN50
# The string columns: chr6:6007387-6007797(NRN1)_HypMET
# The string columns: chr19:22817274-22817546(ZNF492)_HypMET
# The string columns: chr1:11724113-11724885(FBXO6, FBXO44)_HypMET
# The string columns: chr2:175546862-175547880(WIPF1)_HypMET
# The string columns: chr7:22539545-22540022(MGC87042)_HypMET
# The string columns: loss:cnaPANCAN264
# The string columns: loss:cnaPANCAN137 (POT1)
# The string columns: TCF12_mut
# The string columns: loss:cnaPANCAN221
# The string columns: chr22:24110029-24110995(CHCHD10)_HypMET
# The string columns: PSIP1_mut
# The string columns: chr16:67449936-67450472(ZDHHC1)_HypMET
# The string columns: chr3:124449178-124449461(UMPS)_HypMET
# The string columns: loss:cnaPANCAN354
# The string columns: loss:cnaPANCAN396
# The string columns: ZNRF3_mut
# The string columns: chr8:11059011-11059242(XKR6)_HypMET
# The string columns: CDH1_mut
# The string columns: LPHN2_mut
# The string columns: chr1:43613488-43613842(FAM183A)_HypMET
# The string columns: chr17:46654053-46654369(HOXB3)_HypMET
# The string columns: Other, kinases
# The string columns: loss:cnaPANCAN204
# The string columns: chr16:4166655-4167012(ADCY9)_HypMET
# The string columns: HNF1A_mut
# The string columns: MAX_mut
# The string columns: RHOA_mut
# The string columns: loss:cnaPANCAN215
# The string columns: chr11:8615397-8615889(STK33)_HypMET
# The string columns: MACF1_mut
# The string columns: loss:cnaPANCAN46
# The string columns: TSC1_mut
# The string columns: gain:cnaPANCAN271 (NOTCH2)
# The string columns: ITSN1_mut
# The string columns: HSPA8_mut
# The string columns: PI3K/MTOR signaling
# The string columns: PCDH18_mut
# The string columns: loss:cnaPANCAN102
# The string columns: ERK MAPK signaling
# The string columns: loss:cnaPANCAN233
# The string columns: gain:cnaPANCAN60
# The string columns: APAF1_mut
# The string columns: loss:cnaPANCAN103
# The string columns: PBRM1_mut
# The string columns: chr8:61193312-61194195(CA8)_HypMET
# The string columns: chr17:46673532-46674181(LOC404266)_HypMET
# The string columns: chr4:122301567-122302290(QRFPR)_HypMET
# The string columns: gain:cnaPANCAN56
# The string columns: POLR2B_mut
# The string columns: chr3:119298284-119298983(ADPRH)_HypMET
# The string columns: chr13:29292670-29293329(SLC46A3)_HypMET
# The string columns: BMPR2_mut
# The string columns: loss:cnaPANCAN120
# The string columns: AHNAK_mut
# The string columns: loss:cnaPANCAN403
# The string columns: loss:cnaPANCAN415 (B2M,BUB1B,MGA,TP53BP1)
# The string columns: gain:cnaPANCAN376
# The string columns: FAM123B_mut
# The string columns: SVEP1_mut
# The string columns: loss:cnaPANCAN255
# The string columns: FAT1_mut
# The string columns: loss:cnaPANCAN171
# The string columns: chr2:108602824-108603467(SLC5A7)_HypMET
# The string columns: EGFR_mut
# The string columns: gain:cnaPANCAN88 (PABPC1,UBR5)
# The string columns: chr9:115875199-115875738(C9orf109, C9orf110)_HypMET
# The string columns: chr7:128828333-128829366(SMO)_HypMET
# The string columns: loss:cnaPANCAN71 (EXT2)
# The string columns: ALK_mut
# The string columns: loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)
# The string columns: loss:cnaPANCAN261
# The string columns: chr5:50678632-50679375()_HypMET
# The string columns: loss:cnaPANCAN387
# The string columns: loss:cnaPANCAN360
# The string columns: gain:cnaPANCAN124 (EGFR)
# The string columns: loss:cnaPANCAN340
# The string columns: chr1:13910137-13910868(PDPN)_HypMET
# The string columns: KDR_mut
# The string columns: loss:cnaPANCAN116
# The string columns: IGFR signaling
# The string columns: LNPEP_mut
# The string columns: gain:cnaPANCAN299 (TAOK1)
# The string columns: NUP98_mut
# The string columns: MGA_mut
# The string columns: MYH9_mut
# The string columns: loss:cnaPANCAN391 (ING1,IRS2,TFDP1)
# The string columns: chr9:21974578-21975306(CDKN2A)_HypMET
# The string columns: chr10:123922850-123923542(TACC2)_HypMET
# The string columns: chr12:53448008-53448406(TENC1)_HypMET
# The string columns: loss:cnaPANCAN138
# The string columns: DICER1_mut
# The string columns: TCF3-PBX1_mut
# The string columns: chr19:12076029-12076366(ZNF763)_HypMET
# The string columns: chr10:52499392-52500021(ASAH2B)_HypMET
# The string columns: loss:cnaPANCAN197
# The string columns: SPOP_mut
# The string columns: RAC1_mut
# The string columns: chr1:220921411-220922176(MOSC2)_HypMET
# The string columns: RHOT1_mut
# The string columns: SOS2_mut
# The string columns: chr7:32996732-32997591(FKBP9)_HypMET
# The string columns: chr2:219646432-219647181(CYP27A1)_HypMET
# The string columns: loss:cnaPANCAN295 (ATP1A1,CSDE1,NRAS)
# The string columns: TCF7L2_mut
# The string columns: chr21:37442140-37442778(CBR1)_HypMET
# The string columns: LAMA2_mut
# The string columns: HDAC9_mut
# The string columns: loss:cnaPANCAN293
# The string columns: chr19:52390841-52391368(ZNF577)_HypMET
# The string columns: gain:cnaPANCAN192 (FIP1L1,PDGFRA)
# The string columns: BCR-ABL_mut
# The string columns: gain:cnaPANCAN346 (BCL11A,REL,XPO1)
# The string columns: DNA replication
# The string columns: MAGI2_mut
# The string columns: chr10:11059442-11060524(CUGBP2)_HypMET
# The string columns: gain:cnaPANCAN140 (FANCG)
# The string columns: chr7:39649253-39649510()_HypMET
# The string columns: MLLT4_mut
# The string columns: chr14:24803678-24804353(ADCY4, RIPK3)_HypMET
# The string columns: loss:cnaPANCAN40
# The string columns: ETV6-RUNX1_mut
# The string columns: chr17:52977866-52978307(TOM1L1)_HypMET
# The string columns: chr19:53073308-53074039(ZNF701)_HypMET
# The string columns: MLL2_mut
# The string columns: chr17:27503598-27504014(MYO18A)_HypMET
# The string columns: PLCB1_mut
# The string columns: loss:cnaPANCAN285
# The string columns: chr5:101632049-101632373(SLCO4C1)_HypMET
# The string columns: chr20:42543097-42545137(TOX2)_HypMET
# The string columns: loss:cnaPANCAN115
# The string columns: chr16:68002837-68003039(SLC12A4)_HypMET
# The string columns: loss:cnaPANCAN186
# The string columns: loss:cnaPANCAN131
# The string columns: NCOR1_mut
# The string columns: chr17:43339124-43339832(LOC100133991, MAP3K14, C17orf46)_HypMET
# The string columns: loss:cnaPANCAN371
# The string columns: ACVR1B_mut
# The string columns: loss:cnaPANCAN13
# The string columns: chr21:40760626-40760829(WRB)_HypMET
# The string columns: Hormone-related
# The string columns: MAP2K1_mut
# The string columns: TBL1XR1_mut
# The string columns: AHCTF1_mut
# The string columns: loss:cnaPANCAN93
# The string columns: gain:cnaPANCAN244
# The string columns: chr19:53662189-53662500(ZNF347)_HypMET
# The string columns: Chromatin histone methylation
# The string columns: FN1_mut
# The string columns: chr1:1476093-1476669(SSU72)_HypMET
# The string columns: TJP1_mut
# The string columns: gain:cnaPANCAN163 (CHD4,WNK1)
# The string columns: p53 pathway
# The string columns: SF3B1_mut
# The string columns: chr11:8102358-8102913(TUB)_HypMET
# The string columns: chr19:58399945-58400276(ZNF814)_HypMET
# The string columns: loss:cnaPANCAN193
# The string columns: loss:cnaPANCAN39
# The string columns: gain:cnaPANCAN365
# The string columns: loss:cnaPANCAN133
# The string columns: gain:cnaPANCAN58
# The string columns: loss:cnaPANCAN132
# The string columns: chr1:177150814-177151165(FAM5B)_HypMET
# The string columns: loss:cnaPANCAN288
# The string columns: chr2:201983198-201983709(CFLAR)_HypMET
# The string columns: loss:cnaPANCAN266
# The string columns: BLM_mut
# The string columns: chr18:77201938-77202732(NFATC1)_HypMET
# The string columns: NF1_mut
# The string columns: SCAI_mut
# The string columns: chr19:50831454-50832070(KCNC3)_HypMET
# The string columns: chr22:32026297-32026874(PISD)_HypMET
# The string columns: STK11_mut
# The string columns: atom_stereo_count
# The string columns: MAP3K4_mut
# The string columns: chr7:56183577-56184165(LOC389493)_HypMET
# The string columns: TGFBR2_mut
# The string columns: chr2:162270888-162271413()_HypMET
# The string columns: chr12:106532106-106533696(NUAK1)_HypMET
# The string columns: loss:cnaPANCAN157
# The string columns: loss:cnaPANCAN73
# The string columns: gain:cnaPANCAN241 (NCK1,STAG1)
# The string columns: gain:cnaPANCAN246 (SOX2)
# The string columns: CCND1_mut
# The string columns: AXIN2_mut
# The string columns: loss:cnaPANCAN33
# The string columns: loss:cnaPANCAN134
# The string columns: chr3:139258152-139258731(RBP1)_HypMET
# The string columns: chr1:57110663-57111337(PRKAA2)_HypMET
# The string columns: PLXNB2_mut
# The string columns: loss:cnaPANCAN324
# The string columns: GPS2_mut
# The string columns: loss:cnaPANCAN335
# The string columns: gain:cnaPANCAN129 (MET)
# The string columns: chr20:41817475-41819212(PTPRT)_HypMET
# The string columns: loss:cnaPANCAN322
# The string columns: loss:cnaPANCAN317
# The string columns: loss:cnaPANCAN209
# The string columns: ZNF638_mut
# The string columns: chr5:67584213-67584451(PIK3R1)_HypMET
# The string columns: CHD9_mut
# The string columns: chr16:57562451-57563325(CCDC102A)_HypMET
# The string columns: FIP1L1_mut
# The string columns: RASA1_mut
# The string columns: gain:cnaPANCAN211
# The string columns: chr11:506353-508009(RNH1)_HypMET
# The string columns: chr10:94351356-94351615(KIF11)_HypMET
# The string columns: chr2:96011132-96013197(KCNIP3)_HypMET
# The string columns: chr6:52226753-52228006()_HypMET
# The string columns: loss:cnaPANCAN2 (STK11)
# The string columns: loss:cnaPANCAN3 (GNA11)
# The string columns: loss:cnaPANCAN338
# The string columns: chr11:67070807-67071801(SSH3)_HypMET
# The string columns: CHD4_mut
# The string columns: AFF4_mut
# The string columns: chr1:150266476-150266689(MRPS21)_HypMET
# The string columns: loss:cnaPANCAN284
# The string columns: chr3:63263989-63264205(SYNPR)_HypMET
# The string columns: chr7:27195601-27196567(HOXA7)_HypMET
# The string columns: chr16:56665945-56666641(MT1M)_HypMET
# The string columns: CDC73_mut
# The string columns: loss:cnaPANCAN265
# The string columns: gain:cnaPANCAN107 (FUS,TAOK2)
# The string columns: loss:cnaPANCAN216
# The string columns: CDK12_mut
# The string columns: gain:cnaPANCAN28 (CUL2,EPC1)
# The string columns: Cytoskeleton
# The string columns: xlogp
# The string columns: gain:cnaPANCAN272 (PIP5K1A,SETDB1)
# The string columns: gain:cnaPANCAN384 (ERCC5,ING1,IRS2,TFDP1)
# The string columns: gain:cnaPANCAN127 (AKAP9)
# The string columns: chr22:48970857-48972947(FAM19A5)_HypMET
# The string columns: loss:cnaPANCAN169
# The string columns: loss:cnaPANCAN378 (ZNRF3)
# The string columns: CHEK2_mut
# The string columns: loss:cnaPANCAN425
# The string columns: loss:cnaPANCAN101
# The string columns: gain:cnaPANCAN243
# The string columns: chr3:9956822-9957664(IL17RE)_HypMET
# The string columns: EP300_mut
# The string columns: loss:cnaPANCAN161 (NOTCH1)
# The string columns: chr7:35292985-35294674(TBX20)_HypMET
# The string columns: loss:cnaPANCAN172
# The string columns: BRCA1_mut
# The string columns: NTRK2_mut
# The string columns: loss:cnaPANCAN355
# The string columns: chr17:6558221-6558441()_HypMET
# The string columns: chr18:77196121-77196568(NFATC1)_HypMET
# The string columns: chr15:30114110-30115215(TJP1)_HypMET
# The string columns: chr20:33146135-33147318(MAP1LC3A)_HypMET
# The string columns: loss:cnaPANCAN228
# The string columns: ERBB3_mut
# The string columns: molecular_weight
# The string columns: chr8:79428433-79428754(PKIA)_HypMET
# The string columns: CUL3_mut
# The string columns: loss:cnaPANCAN65
# The string columns: loss:cnaPANCAN32
# The string columns: ZFHX3_mut
# The string columns: loss:cnaPANCAN5
# The string columns: H
# The string columns: gain:cnaPANCAN411 (BLM,CRTC3,FANCI,IDH2,NR2F2,PCSK6)
# The string columns: CAD_mut
# The string columns: BRAF_mut
# The string columns: SETDB1_mut
# The string columns: loss:cnaPANCAN16
# The string columns: MYH11_mut
# The string columns: loss:cnaPANCAN419
# The string columns: loss:cnaPANCAN222
# The string columns: loss:cnaPANCAN94
# The string columns: gain:cnaPANCAN375
# The string columns: gain:cnaPANCAN212 (HSP90AB1,TRERF1)
# The string columns: rotatable_bond_count
# The string columns: loss:cnaPANCAN424
# The string columns: chr6:48036137-48036410(C6orf138)_HypMET
# The string columns: chr9:123555399-123555899(FBXW2)_HypMET
# The string columns: AKAP9_mut
# The string columns: ELF3_mut
# The string columns: ZFP36L2_mut
# The string columns: SRGAP3_mut
# The string columns: chr10:135122851-135123109(ZNF511, TUBGCP2)_HypMET
# The string columns: loss:cnaPANCAN294
# The string columns: RBM5_mut
# The string columns: loss:cnaPANCAN327
# The string columns: loss:cnaPANCAN6
# The string columns: chr11:43902254-43902528(ALKBH3)_HypMET
# The string columns: chr19:22018594-22018827(ZNF43)_HypMET
# The string columns: h_bond_acceptor_count
# The string columns: loss:cnaPANCAN282
# The string columns: NSD1_mut
# The string columns: loss:cnaPANCAN62 (HRAS,IRF7)
# The string columns: chr1:143912736-143916156(FAM72D)_HypMET
# The string columns: loss:cnaPANCAN151
# The string columns: chr1:218520287-218520506(TGFB2)_HypMET
# The string columns: CNOT1_mut
# The string columns: chr22:47022457-47022659()_HypMET
# The string columns: chr19:52531323-52531724(ZNF614)_HypMET
# The string columns: KDM6A_mut
# The string columns: loss:cnaPANCAN370
# The string columns: loss:cnaPANCAN45
# The string columns: loss:cnaPANCAN158
# The string columns: loss:cnaPANCAN168
# The string columns: loss:cnaPANCAN410
# The string columns: chr5:73935725-73937551(ENC1)_HypMET
# The string columns: SRGAP1_mut
# The string columns: loss:cnaPANCAN112 (CREBBP)
# The string columns: loss:cnaPANCAN183
# The string columns: chr20:30192854-30194025(ID1)_HypMET
# The string columns: STIP1_mut
# The string columns: loss:cnaPANCAN318
# The string columns: gain:cnaPANCAN366
# The string columns: loss:cnaPANCAN217
# The string columns: chr17:44656490-44657494(ARL17A)_HypMET
# The string columns: ACVR2A_mut
# The string columns: gain:cnaPANCAN245 (MECOM)
# The string columns: RBM10_mut
# The string columns: loss:cnaPANCAN408
# The string columns: loss:cnaPANCAN173
# The string columns: DLG1_mut
# The string columns: complexity
# The string columns: undefined_atom_stereo_count
# The string columns: EZH2_mut
# The string columns: chr10:105253191-105254428(NEURL)_HypMET
# The string columns: chr6:27858166-27858564()_HypMET
# The string columns: F8_mut
# The string columns: WT1_mut
# The string columns: loss:cnaPANCAN319
# The string columns: chr6:150067323-150067766(NUP43)_HypMET
# The string columns: chr8:107669777-107670591(OXR1)_HypMET
# The string columns: NUP93_mut
# The string columns: chr1:53904140-53905247(FLJ40434)_HypMET
# The string columns: ABL2_mut
# The string columns: gain:cnaPANCAN363 (ASXL1)
# The string columns: loss:cnaPANCAN145 (FANCG,PAX5)
# The string columns: loss:cnaPANCAN42 (ANK3)
# The string columns: chr16:48399730-48400040(SIAH1)_HypMET
# The string columns: loss:cnaPANCAN175
# The string columns: chr1:171810467-171811325(DNM3)_HypMET
# The string columns: CDC27_mut
# The string columns: chr3:53527927-53530106(CACNA1D)_HypMET
# The string columns: gain:cnaPANCAN190 (FGFR3,WHSC1)
# The string columns: gain:cnaPANCAN87
# The string columns: ARAP3_mut
# The string columns: chr5:126626053-126626901(MEGF10)_HypMET
# The string columns: CLOCK_mut
# The string columns: loss:cnaPANCAN184 (APC)
# The string columns: MCM3_mut
# The string columns: TRIO_mut
# The string columns: chr11:73693702-73694802(UCP2)_HypMET
# The string columns: chr8:67344497-67344989(RRS1)_HypMET
# The string columns: SMARCB1_mut
# The string columns: loss:cnaPANCAN79
# The string columns: loss:cnaPANCAN267
# The string columns: gain:cnaPANCAN330 (RPGR)
# The string columns: loss:cnaPANCAN152
# The string columns: AXIN1_mut
# The string columns: CTNNB1_mut
# The string columns: chr4:76555366-76556079(CDKL2)_HypMET
# The string columns: gain:cnaPANCAN236
# The string columns: loss:cnaPANCAN328
# The string columns: loss:cnaPANCAN292
# The string columns: gain:cnaPANCAN83
# The string columns: chr5:1594238-1595027(SDHAP3)_HypMET
# The string columns: chr17:46691520-46692097(HOXB8)_HypMET
# The string columns: loss:cnaPANCAN306
# The string columns: loss:cnaPANCAN353
# The string columns: chr19:1851578-1852203()_HypMET
# The string columns: chr2:74875128-74875562(C2orf65)_HypMET
# The string columns: chr2:29337983-29338909(CLIP4)_HypMET
# The string columns: loss:cnaPANCAN226
# The string columns: chr6:55443732-55444092(HMGCLL1)_HypMET
# The string columns: chr19:40871617-40871824(PLD3)_HypMET
# The string columns: loss:cnaPANCAN290
# The string columns: loss:cnaPANCAN232
# The string columns: gain:cnaPANCAN275 (SDHC)
# The string columns: chr20:48098512-48099560(KCNB1)_HypMET
# The string columns: ARFGAP3_mut
# The string columns: HRAS_mut
# The string columns: ARHGAP29_mut
# The string columns: loss:cnaPANCAN74
# The string columns: loss:cnaPANCAN224
# The string columns: loss:cnaPANCAN187
# The string columns: loss:cnaPANCAN146 (GNAQ,NTRK2,PCSK5,TJP2)
# The string columns: gain:cnaPANCAN86
# The string columns: gain:cnaPANCAN166 (MDM2,NUP107,SRGAP1)
# The string columns: gain:cnaPANCAN164 (KRAS)
# The string columns: chr9:98783216-98784364(NCRNA00092)_HypMET
# The string columns: chr7:87256958-87258444(RUNDC3B, ABCB1)_HypMET
# The string columns: loss:cnaPANCAN82
# The string columns: loss:cnaPANCAN230 (SYNCRIP,ZNF292)
# The string columns: PIK3CA_mut
# The string columns: chr3:42304944-42305311(CCK)_HypMET
# The string columns: chr11:72463092-72463717(ARAP1)_HypMET
# The string columns: loss:cnaPANCAN37
# The string columns: gain:cnaPANCAN121 (ACTB,CARD11,PMS2,RAC1)
# The string columns: loss:cnaPANCAN155
# The string columns: chr3:10206449-10207024(IRAK2)_HypMET
# The string columns: loss:cnaPANCAN153 (ABL1)
# The string columns: ABL signaling
# The string columns: MKL1_mut
# The string columns: loss:cnaPANCAN406
# The string columns: BRWD1_mut
# The string columns: loss:cnaPANCAN189
# The string columns: FXR1_mut
# The string columns: chr8:61626645-61627074(CHD7)_HypMET
# The string columns: loss:cnaPANCAN207
# The string columns: chr19:54371854-54372990(MYADM)_HypMET
# The string columns: chr4:6200912-6202724(JAKMIP1)_HypMET
# The string columns: loss:cnaPANCAN315 (NF1,SUZ12)
# The string columns: 3bonds
# The string columns: SOS1_mut
# The string columns: gain:cnaPANCAN302 (CLTC,PPM1D)
# The string columns: chr1:42127380-42128632(HIVEP3)_HypMET
# The string columns: gain:cnaPANCAN141 (GNAQ,NTRK2,PCSK5,TJP2)
# The string columns: gain:cnaPANCAN274
# The string columns: gain:cnaPANCAN238
# The string columns: ERBB2_mut
# The string columns: loss:cnaPANCAN414
# The string columns: chr15:93198374-93199181(FAM174B)_HypMET
# The string columns: chr17:38333605-38334795(RAPGEFL1)_HypMET
# The string columns: chr11:64509433-64513826(RASGRP2)_HypMET
# The string columns: loss:cnaPANCAN420
# The string columns: SPTAN1_mut
# The string columns: chr4:66535193-66535620(EPHA5)_HypMET
# The string columns: CDKN1A_mut
# The string columns: chr15:81426499-81426702(C15orf26)_HypMET
# The string columns: WHSC1L1_mut
# The string columns: gain:cnaPANCAN352 (PMS1)
# The string columns: chr9:35756948-35757339(MSMP)_HypMET
# The string columns: CLSPN_mut
# The string columns: chr2:85811340-85811855(VAMP5)_HypMET
# The string columns: chr6:26250436-26250827(HIST1H2BH, HIST1H3F)_HypMET
# The string columns: gain:cnaPANCAN350
# The string columns: TP53BP1_mut
# The string columns: loss:cnaPANCAN423
# The string columns: chr4:102711829-102712199(BANK1)_HypMET
# The string columns: chr7:750788-751237(PRKAR1B)_HypMET
# The string columns: loss:cnaPANCAN252
# The string columns: loss:cnaPANCAN281 (RPL22)
# The string columns: chr1:145472980-145474702(ANKRD34A)_HypMET
# The string columns: loss:cnaPANCAN325
# The string columns: gain:cnaPANCAN395 (AKT1,HSP90AA1,PPP2R5C)
# The string columns: loss:cnaPANCAN412
# The string columns: chr1:121260857-121261525(LOC647121)_HypMET
# The string columns: WNK1_mut
# The string columns: loss:cnaPANCAN156
# The string columns: RNF43_mut
# The string columns: SACS_mut
# The string columns: FRG1B_mut
# The string columns: chr11:65408344-65408631(SIPA1)_HypMET
# The string columns: PTPRU_mut
# The string columns: gain:cnaPANCAN85 (SOX17)
# The string columns: MLH3_mut
# The string columns: loss:cnaPANCAN15
# The string columns: chr2:232650898-232651431(COPS7B)_HypMET
# The string columns: chr5:175792355-175793505(ARL10)_HypMET
# The string columns: CASP8_mut
# The string columns: MAP3K1_mut
# The string columns: chr1:40782220-40783145(COL9A2)_HypMET
# The string columns: TJP2_mut
# The string columns: chr1:21996161-21996409(RAP1GAP)_HypMET
# The string columns: chr18:14132000-14132482(ZNF519)_HypMET
# The string columns: loss:cnaPANCAN17
# The string columns: loss:cnaPANCAN136
# The string columns: loss:cnaPANCAN26
# The string columns: TP53_mut
# The string columns: gain:cnaPANCAN108 (CHD9,CYLD)
# The string columns: loss:cnaPANCAN81
# The string columns: MEN1_mut
# The string columns: loss:cnaPANCAN388
# The string columns: chr19:58144339-58144999(ZNF211)_HypMET
# The string columns: loss:cnaPANCAN422
# The string columns: NF2_mut
# The string columns: loss:cnaPANCAN234
# The string columns: gain:cnaPANCAN191 (FIP1L1,PDGFRA)
# The string columns: chr19:12266998-12267686(ZNF625)_HypMET
# The string columns: loss:cnaPANCAN286
# The string columns: loss:cnaPANCAN310 (MAP2K4)
# The string columns: chr17:66596072-66597578(FAM20A)_HypMET
# The string columns: chr14:23834435-23835947(EFS)_HypMET
# The string columns: SMC1A_mut
# The string columns: chr9:140310894-140312457(EXD3)_HypMET
# The string columns: chr15:60690708-60690930(ANXA2)_HypMET
# The string columns: loss:cnaPANCAN402
# The string columns: chr4:129208297-129209780(PGRMC2)_HypMET
# The string columns: loss:cnaPANCAN308
# The string columns: chr10:106028542-106029047(GSTO2)_HypMET
# The string columns: STAG1_mut
# The string columns: chr1:120835961-120839391(FAM72B)_HypMET
# The string columns: CHD8_mut
# The string columns: loss:cnaPANCAN12
# The string columns: gain:cnaPANCAN139
# The string columns: RGS3_mut
# The string columns: SMARCA1_mut
# The string columns: loss:cnaPANCAN379
# The string columns: gain:cnaPANCAN248 (EIF4A2,RFC4)
# The string columns: chr7:27186927-27187692(HOXA6)_HypMET
# The string columns: loss:cnaPANCAN69
# The string columns: loss:cnaPANCAN398
# The string columns: gain:cnaPANCAN91 (MYC)
# The string columns: CREBBP_mut
# The string columns: gain:cnaPANCAN178
# The string columns: gain:cnaPANCAN143 (NOTCH1)
# The string columns: chr3:10857687-10858447(SLC6A11)_HypMET
# The string columns: heavy_atom_count
# The string columns: chr10:43891546-43892917(HNRNPF)_HypMET
# The string columns: chr15:45722561-45722939()_HypMET
# The string columns: chr2:9346383-9347944(ASAP2)_HypMET
# The string columns: CHD6_mut
# The string columns: ZNF292_mut
# The string columns: gain:cnaPANCAN90
# The string columns: CUX1_mut
# The string columns: chr1:181451311-181452049()_HypMET
# The string columns: chr4:5709985-5710495(EVC2)_HypMET
# The string columns: loss:cnaPANCAN342
# The string columns: chr6:29759946-29760903(HCG4)_HypMET
# The string columns: MAP2K4_mut
# The string columns: loss:cnaPANCAN206
# The string columns: MYCN_mut
# The string columns: chr5:157002174-157003182(ADAM19)_HypMET
# The string columns: chr17:42092143-42092432(TMEM101)_HypMET
# The string columns: chr7:100136448-100136919(AGFG2)_HypMET
# The string columns: chr8:22422534-22423702(SORBS3)_HypMET
# The string columns: loss:cnaPANCAN35 (CUL2)
# The string columns: gain:cnaPANCAN126
# The string columns: MAP4K3_mut
# The string columns: chr6:26188997-26189295(HIST1H4D)_HypMET
# The string columns: Cl
# The string columns: MAX_CONC
# The string columns: chr15:30685087-30685891(CHRFAM7A)_HypMET
# The string columns: gain:cnaPANCAN276
# The string columns: loss:cnaPANCAN258
# The string columns: loss:cnaPANCAN321
# The string columns: chr2:136499145-136500144(UBXN4)_HypMET
# The string columns: loss:cnaPANCAN198
# The string columns: chr2:218621279-218621498(DIRC3)_HypMET
# The string columns: MED12_mut
# The string columns: loss:cnaPANCAN208 (PCDH18)
# The string columns: loss:cnaPANCAN30 (LARP4B)
# The string columns: chr1:33938025-33938328(ZSCAN20)_HypMET
# The string columns: SEC31A_mut
# The string columns: chr11:66247269-66248249(DPP3)_HypMET
# The string columns: MET_mut
# The string columns: loss:cnaPANCAN75 (MED17)
# The string columns: chr2:152954633-152955784(CACNB4)_HypMET
# The string columns: chr14:61188116-61190772(SIX4)_HypMET
# The string columns: loss:cnaPANCAN256 (CACNA1D,WNT5A)
# The string columns: loss:cnaPANCAN263
# The string columns: loss:cnaPANCAN31
# The string columns: PCSK5_mut
# The string columns: chr19:11998804-11999131(ZNF69)_HypMET
# The string columns: loss:cnaPANCAN200
# The string columns: INPP4A_mut
# The string columns: TAOK1_mut
# The string columns: chr6:39901852-39902299(MOCS1)_HypMET
# The string columns: FGFR2_mut
# The string columns: chr17:41363727-41364273(TMEM106A)_HypMET
# The string columns: loss:cnaPANCAN404
# The string columns: gain:cnaPANCAN29 (KAT6B)
# The string columns: AMOT_mut
# The string columns: ARID1B_mut
# The string columns: FOXP1_mut
# The string columns: chr19:48949034-48949442(GRWD1)_HypMET
# The string columns: NTN4_mut
# The string columns: chr11:44087518-44088165(ACCS)_HypMET
# The string columns: ROBO2_mut
# The string columns: gain:cnaPANCAN105
# The string columns: loss:cnaPANCAN55
# The string columns: loss:cnaPANCAN4
# The string columns: loss:cnaPANCAN24
# The string columns: CNOT3_mut
# The string columns: loss:cnaPANCAN337
# The string columns: INPPL1_mut
# The string columns: loss:cnaPANCAN409
# The string columns: loss:cnaPANCAN20
# The string columns: chr19:12831793-12832225(TNPO2)_HypMET
# The string columns: ASH1L_mut
# The string columns: chr19:47731377-47731715(BBC3)_HypMET
# The string columns: MLL3_mut
# The string columns: loss:cnaPANCAN312
# The string columns: IREB2_mut
# The string columns: loss:cnaPANCAN309
# The string columns: chr19:11689417-11689768(ACP5)_HypMET
# The string columns: loss:cnaPANCAN179
# The string columns: THRAP3_mut
# The string columns: EIF4G1_mut
# The string columns: PIK3R1_mut
# The string columns: chr19:48945800-48947636(GRIN2D)_HypMET
# The string columns: chr19:56915356-56915856(ZNF583)_HypMET
# The string columns: PLXNA1_mut
# The string columns: chr1:248100325-248100726(OR2L13)_HypMET
# The string columns: Metabolism
# The string columns: chr6:31148369-31148577(PSORS1C3)_HypMET
# The string columns: COL1A1_mut
# The string columns: chr9:4984543-4985630(JAK2)_HypMET
# The string columns: DHX15_mut
# The string columns: chr5:125930601-125931049(ALDH7A1)_HypMET
# The string columns: loss:cnaPANCAN304
# The string columns: loss:cnaPANCAN283
# The string columns: EIF4G3_mut
# The string columns: chr1:110230238-110230614(GSTM1)_HypMET
# The string columns: MED23_mut
# The string columns: chr20:61636171-61639055()_HypMET
# The string columns: loss:cnaPANCAN110
# The string columns: SIN3A_mut
# The string columns: chr17:40932329-40933299(WNK4)_HypMET
# The string columns: gain:cnaPANCAN239 (FOXP1,MITF)
# The string columns: CUL2_mut
# The string columns: chr18:77193463-77193764(NFATC1)_HypMET
# The string columns: DNMT3A_mut
# The string columns: loss:cnaPANCAN313
# The string columns: chr21:47601020-47601229(C21orf56)_HypMET
# The string columns: loss:cnaPANCAN117 (CHD9,CNOT1,CYLD,MMP2,NUP93)
# The string columns: loss:cnaPANCAN400
# The string columns: chr3:187456250-187456580(BCL6)_HypMET
# The string columns: BPTF_mut
# The string columns: PTEN_mut
# The string columns: BCOR_mut
# The string columns: F
# The string columns: CLASP2_mut
# The string columns: NOTCH1_mut
# The string columns: loss:cnaPANCAN235 (ARID1B,MAP3K4,MLLT4)
# The string columns: loss:cnaPANCAN390
# The string columns: PTPN11_mut
# The string columns: chr22:24180491-24181666(DERL3)_HypMET
# The string columns: CCAR1_mut
# The string columns: chr3:36985540-36987041(TRANK1)_HypMET
# The string columns: KALRN_mut
# The string columns: loss:cnaPANCAN54
# The string columns: chr3:125075915-125076481(ZNF148)_HypMET
# The string columns: loss:cnaPANCAN231
# The string columns: PHF6_mut
# The string columns: PHLPP1_mut
# The string columns: loss:cnaPANCAN49
# The string columns: gain:cnaPANCAN214
# The string columns: ZMYM2_mut
# The string columns: chr14:24457864-24458100(DHRS4L2)_HypMET
# The string columns: EWSR1-FLI1_mut
# The string columns: G3BP2_mut
# The string columns: loss:cnaPANCAN202
# The string columns: RPGR_mut
# The string columns: WNT signaling
# The string columns: CIC_mut
# The string columns: chr5:180017099-180019062(SCGB3A1)_HypMET
# The string columns: loss:cnaPANCAN80 (SDHD)
# The string columns: Apoptosis regulation
# The string columns: loss:cnaPANCAN326 (SOX9)
# The string columns: SMARCA4_mut
# The string columns: 2bonds
# The string columns: gain:cnaPANCAN57 (CAT)
# The string columns: CHD3_mut
# The string columns: CTNND1_mut
# The string columns: loss:cnaPANCAN421
# The string columns: LIMA1_mut
# The string columns: BAP1_mut
# The string columns: chr7:27203915-27206462(HOXA9)_HypMET
# The string columns: XPO1_mut
# The string columns: chr16:67183208-67184968(B3GNT9)_HypMET
# The string columns: MLH1_mut
# The string columns: BCLAF1_mut
# The string columns: chr6:90142751-90143635(ANKRD6)_HypMET
# The string columns: Protein stability and degradation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d7aabf48f323> in <module>()
#      12 results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use,
#      13                          features_to_scale=columns_for_normalisation, scaling = True,
# ---> 14                          print_results=False)
#
# <ipython-input-4-6a6c9965ce86> in TuneParameters(train, number_coefficients, kernels, column_not_to_use, param_tested, param_tested_values, alpha, gamma, degree, coef0, features_to_scale, scaling, print_results)
#     222                                             param_tested = "alpha", param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500],
#     223                                             features_to_scale = features_to_scale, scaling = scaling,
# --> 224                                             print_results=print_results)
#     225
#     226             print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
#
# <ipython-input-4-6a6c9965ce86> in RunCrossValidation(train, number_coefficients, column_not_to_use, kernel, param_tested, param_tested_values, alpha, gamma, degree, coef0, features_to_scale, scaling, print_results)
#     127
#     128             # mse is more sensitive to different parameters choice
# --> 129             mse = LeaveOneOutError(kernel_model, X_train, y_train, metrics="mse")
#     130             df_errors.loc["mse", "mse_coef"+str(i+1)+"_"+str(param)] = mse
#     131
#
# <ipython-input-4-6a6c9965ce86> in LeaveOneOutError(kernel_model, X, y, metrics)
#      37         y_train_loo, y_test_loo = y[train_index], y[test_index]
#      38
# ---> 39         model = kernel_model.fit(X_train_loo, y_train_loo)
#      40         if metrics == "mse":
#      41             mse = mean_squared_error(y_test_loo, model.predict(X_test_loo))
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/kernel_ridge.py in fit(self, X, y, sample_weight)
#     150         # Convert data
#     151         X, y = check_X_y(X, y, accept_sparse=("csr", "csc"), multi_output=True,
# --> 152                          y_numeric=True)
#     153         if sample_weight is not None and not isinstance(sample_weight, float):
#     154             sample_weight = check_array(sample_weight, ensure_2d=False)
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Microtubule stabiliser'

# %%
print("Tuned parameters:")
print(results)
print("\nBetter presentation:")
for key in results:
    print(key,"\t", results[key])

best_kernels, df_results = TrainTestBestParameters(train, test, 4, kernels = kernels_to_test, 
                                                       column_not_to_use=column_not_to_use, 
                                                       best_parameters_dict = results, 
                                                       features_to_scale=columns_for_normalisation, scaling = True,
                                                       print_results=True)
print("Best Kernels:", best_kernels)

print("\nAll results\n")
print(df_results)
# Out:
# 13
# The string columns: loss:cnaPANCAN397
# The string columns: NCOR2_mut
# The string columns: chr19:58458686-58459219(ZNF256)_HypMET
# The string columns: XRN1_mut
# The string columns: loss:cnaPANCAN148
# The string columns: loss:cnaPANCAN254
# The string columns: chr16:3355020-3356012(TIGD7)_HypMET
# The string columns: chr4:165878036-165878446(C4orf39, TRIM61)_HypMET
# The string columns: chr10:102891010-102891794(TLX1NB, TLX1)_HypMET
# The string columns: gain:cnaPANCAN348
# The string columns: loss:cnaPANCAN329 (ZNF750)
# The string columns: STK4_mut
# The string columns: loss:cnaPANCAN361
# The string columns: loss:cnaPANCAN225
# The string columns: chr5:63461448-63462106()_HypMET
# The string columns: TET2_mut
# The string columns: gain:cnaPANCAN27 (GATA3,KLF6,LARP4B,VIM)
# The string columns: chr7:119912840-119913883(KCND2)_HypMET
# The string columns: TNPO1_mut
# The string columns: ASXL1_mut
# The string columns: BNC2_mut
# The string columns: NR4A2_mut
# The string columns: MED24_mut
# The string columns: chr4:1005930-1006282(FGFRL1)_HypMET
# The string columns: gain:cnaPANCAN268
# The string columns: chr5:35617855-35618339(SPEF2)_HypMET
# The string columns: loss:cnaPANCAN298
# The string columns: ANK3_mut
# The string columns: chr14:70345943-70346527(SMOC1)_HypMET
# The string columns: chr19:49315545-49315765(BCAT2)_HypMET
# The string columns: U2AF1_mut
# The string columns: loss:cnaPANCAN316
# The string columns: gain:cnaPANCAN279
# The string columns: chr14:48143433-48145589(MDGA2)_HypMET
# The string columns: SMAD2_mut
# The string columns: chr7:62858468-62858826(LOC100287834)_HypMET
# The string columns: chr3:56502611-56502815(ERC2)_HypMET
# The string columns: chr20:62433937-62434203(ZBTB46)_HypMET
# The string columns: loss:cnaPANCAN174
# The string columns: chr18:47087879-47088528(LIPG)_HypMET
# The string columns: ERBB2IP_mut
# The string columns: loss:cnaPANCAN399
# The string columns: JNK and p38 signaling
# The string columns: chr12:132690339-132690571(GALNT9)_HypMET
# The string columns: NPM1_mut
# The string columns: chr11:75378416-75379882(MAP6)_HypMET
# The string columns: S
# The string columns: ARFGEF2_mut
# The string columns: loss:cnaPANCAN357 (ACVR2A)
# The string columns: CDKN2A_mut
# The string columns: gain:cnaPANCAN344 (MYCN)
# The string columns: chr18:77905297-77905566(LOC100130522)_HypMET
# The string columns: loss:cnaPANCAN417
# The string columns: loss:cnaPANCAN66
# The string columns: gain:cnaPANCAN240
# The string columns: loss:cnaPANCAN257
# The string columns: chr14:59930634-59932251()_HypMET
# The string columns: chr20:61560433-61560954(DIDO1)_HypMET
# The string columns: chr15:64679907-64680233(TRIP4)_HypMET
# The string columns: chr19:15342626-15343181(EPHX3)_HypMET
# The string columns: loss:cnaPANCAN53
# The string columns: gain:cnaPANCAN331
# The string columns: chr7:143582125-143582610(FAM115A)_HypMET
# The string columns: MYH14_mut
# The string columns: loss:cnaPANCAN68
# The string columns: gain:cnaPANCAN362 (CRNKL1,FOXA2)
# The string columns: loss:cnaPANCAN377
# The string columns: CTCF_mut
# The string columns: loss:cnaPANCAN150 (PTGS1)
# The string columns: formal_charge
# The string columns: Chromatin other
# The string columns: gain:cnaPANCAN345
# The string columns: chr18:5543437-5544241(EPB41L3)_HypMET
# The string columns: gain:cnaPANCAN18
# The string columns: EIF4A2_mut
# The string columns: loss:cnaPANCAN38
# The string columns: MNDA_mut
# The string columns: gain:cnaPANCAN269 (MACF1)
# The string columns: chr19:50706482-50707196(MYH14)_HypMET
# The string columns: loss:cnaPANCAN154
# The string columns: ARID5B_mut
# The string columns: Cell cycle
# The string columns: ABCB1_mut
# The string columns: ADCY1_mut
# The string columns: gain:cnaPANCAN382 (FLT3,WASF3)
# The string columns: I
# The string columns: chr20:47443734-47445181(PREX1)_HypMET
# The string columns: LRP6_mut
# The string columns: chr2:21022564-21022934(C2orf43)_HypMET
# The string columns: chr9:35791584-35791924(NPR2)_HypMET
# The string columns: loss:cnaPANCAN262 (FOXP1)
# The string columns: chr7:99678768-99679702(ZNF3)_HypMET
# The string columns: ARID1A_mut
# The string columns: chr12:50297580-50297988(FAIM2)_HypMET
# The string columns: loss:cnaPANCAN291 (JAK1)
# The string columns: chr13:96296143-96297059(DZIP1)_HypMET
# The string columns: chr5:179243545-179244453(SQSTM1)_HypMET
# The string columns: EWSR1-X_mut
# The string columns: loss:cnaPANCAN334
# The string columns: ARFGEF1_mut
# The string columns: loss:cnaPANCAN77 (CASP1)
# The string columns: RTK signaling
# The string columns: loss:cnaPANCAN251
# The string columns: WHSC1_mut
# The string columns: chr22:19746924-19747141(TBX1)_HypMET
# The string columns: chr12:39299248-39299629(CPNE8)_HypMET
# The string columns: KRAS_mut
# The string columns: TBX3_mut
# The string columns: chr13:27131568-27132677()_HypMET
# The string columns: surface_area
# The string columns: loss:cnaPANCAN11
# The string columns: gain:cnaPANCAN242 (PIK3CB)
# The string columns: RASA2_mut
# The string columns: chr19:41106058-41106415(LTBP4)_HypMET
# The string columns: loss:cnaPANCAN401
# The string columns: N
# The string columns: PIK3C2B_mut
# The string columns: PIK3CB_mut
# The string columns: RUNX1-RUNX1T1_mut
# The string columns: chr13:43566074-43566508(EPSTI1)_HypMET
# The string columns: loss:cnaPANCAN47
# The string columns: FAF1_mut
# The string columns: loss:cnaPANCAN289 (CDKN2C,FAF1)
# The string columns: loss:cnaPANCAN195
# The string columns: ASXL2_mut
# The string columns: gain:cnaPANCAN347
# The string columns: SMAD4_mut
# The string columns: chr1:153935781-153936276(SLC39A1)_HypMET
# The string columns: loss:cnaPANCAN358
# The string columns: ASPM_mut
# The string columns: USP6_mut
# The string columns: EWRS1-ERG_mut
# The string columns: SOX9_mut
# The string columns: loss:cnaPANCAN100
# The string columns: chr19:42501261-42501486(ATP1A3)_HypMET
# The string columns: chr13:36052553-36053119(MIR548F5, NBEA, MAB21L1)_HypMET
# The string columns: MYC_mut
# The string columns: GATA3_mut
# The string columns: chr10:135043221-135044560(UTF1)_HypMET
# The string columns: PTCH1_mut
# The string columns: gain:cnaPANCAN213 (MCM3)
# The string columns: loss:cnaPANCAN219
# The string columns: loss:cnaPANCAN194 (FGFR3)
# The string columns: loss:cnaPANCAN386
# The string columns: chr20:30310503-30310707(BCL2L1)_HypMET
# The string columns: chr18:10454453-10455268(APCDD1)_HypMET
# The string columns: loss:cnaPANCAN160
# The string columns: chr2:183731819-183732093(FRZB)_HypMET
# The string columns: NOTCH2_mut
# The string columns: MLL_mut
# The string columns: loss:cnaPANCAN63
# The string columns: chr12:104697348-104697984(EID3, TXNRD1)_HypMET
# The string columns: Mitosis
# The string columns: chr8:95652455-95652873(ESRP1)_HypMET
# The string columns: gain:cnaPANCAN394 (GNG2,SOS2)
# The string columns: loss:cnaPANCAN98
# The string columns: loss:cnaPANCAN359 (CUL3)
# The string columns: gain:cnaPANCAN177 (IL7R)
# The string columns: chr7:27225050-27225629(HOXA11AS, HOXA11)_HypMET
# The string columns: FTSJD1_mut
# The string columns: chr3:194406440-194409045(FAM43A)_HypMET
# The string columns: chr6:26045644-26046033()_HypMET
# The string columns: chr3:101568107-101569046(NFKBIZ)_HypMET
# The string columns: chr7:150065169-150066351(REPIN1)_HypMET
# The string columns: loss:cnaPANCAN201
# The string columns: loss:cnaPANCAN188
# The string columns: NRAS_mut
# The string columns: chr4:57371582-57372022(ARL9)_HypMET
# The string columns: chr8:144659745-144660635(NAPRT1)_HypMET
# The string columns: loss:cnaPANCAN10 (CIC)
# The string columns: ELF1_mut
# The string columns: chr1:180881316-180882592(KIAA1614)_HypMET
# The string columns: LRPPRC_mut
# The string columns: Br
# The string columns: KDM5C_mut
# The string columns: RAD21_mut
# The string columns: loss:cnaPANCAN43
# The string columns: EPHA4_mut
# The string columns: gain:cnaPANCAN59 (CCND1,CTTN)
# The string columns: chr9:104248247-104249501(C9orf125)_HypMET
# The string columns: chr4:103940668-103940951(NHEDC1)_HypMET
# The string columns: loss:cnaPANCAN25
# The string columns: chr1:60539315-60539540(C1orf87)_HypMET
# The string columns: chr17:46655215-46655604(HOXB4)_HypMET
# The string columns: gain:cnaPANCAN351 (NFE2L2)
# The string columns: PLCG1_mut
# The string columns: KAT6B_mut
# The string columns: GNA11_mut
# The string columns: chr12:3862068-3862606(EFCAB4B)_HypMET
# The string columns: loss:cnaPANCAN199
# The string columns: chr19:58011124-58011743(ZNF773)_HypMET
# The string columns: chr12:49782965-49783193(SPATS2)_HypMET
# The string columns: chr13:79175610-79177985(POU4F1)_HypMET
# The string columns: chr19:44763978-44764312(ZNF233)_HypMET
# The string columns: chr3:49314437-49314815(C3orf62)_HypMET
# The string columns: chr9:86571047-86572027(C9orf64)_HypMET
# The string columns: loss:cnaPANCAN118 (ZFHX3)
# The string columns: chr22:20790638-20792665(SCARF2)_HypMET
# The string columns: gain:cnaPANCAN128
# The string columns: gain:cnaPANCAN392 (CHD8)
# The string columns: Chromatin histone acetylation
# The string columns: FLT3_mut
# The string columns: loss:cnaPANCAN22
# The string columns: gain:cnaPANCAN122 (AHR,HDAC9)
# The string columns: chr10:48438411-48439320(GDF10)_HypMET
# The string columns: chr8:11058624-11058844(XKR6)_HypMET
# The string columns: loss:cnaPANCAN373
# The string columns: loss:cnaPANCAN413
# The string columns: loss:cnaPANCAN149
# The string columns: chr19:37957726-37958390(ZNF569)_HypMET
# The string columns: gain:cnaPANCAN393 (FOXA1,NKX2-1,PSMA6)
# The string columns: KIT_mut
# The string columns: C15orf55_mut
# The string columns: GNAS_mut
# The string columns: chr5:59189046-59189894(PDE4D)_HypMET
# The string columns: loss:cnaPANCAN389 (RB1)
# The string columns: ARHGAP26_mut
# The string columns: chr19:53496732-53497028()_HypMET
# The string columns: AKT1_mut
# The string columns: gain:cnaPANCAN303
# The string columns: loss:cnaPANCAN385 (PABPC3,SACS,ZMYM2)
# The string columns: loss:cnaPANCAN34
# The string columns: loss:cnaPANCAN418
# The string columns: covalent_unit_count
# The string columns: loss:cnaPANCAN92
# The string columns: loss:cnaPANCAN147
# The string columns: chr11:113185332-113185663(TTC12)_HypMET
# The string columns: chr3:99594969-99595215(C3orf26, FILIP1L, MIR548G)_HypMET
# The string columns: ATM_mut
# The string columns: loss:cnaPANCAN314
# The string columns: loss:cnaPANCAN78 (CASP1)
# The string columns: chr1:214161197-214161415(PROX1)_HypMET
# The string columns: loss:cnaPANCAN356 (ERCC3)
# The string columns: chr15:40544352-40545512(PAK6, C15orf56)_HypMET
# The string columns: HGF_mut
# The string columns: LARP4B_mut
# The string columns: gain:cnaPANCAN130 (RHEB)
# The string columns: loss:cnaPANCAN297
# The string columns: chr1:1167001-1168985(SDF4, B3GALT6)_HypMET
# The string columns: chr5:115912001-115912384(SEMA6A)_HypMET
# The string columns: gain:cnaPANCAN106
# The string columns: loss:cnaPANCAN311
# The string columns: gain:cnaPANCAN333 (F8,HCFC1,RPL10)
# The string columns: loss:cnaPANCAN381 (ARFGAP3)
# The string columns: chr3:238391-240140(CHL1)_HypMET
# The string columns: loss:cnaPANCAN21
# The string columns: loss:cnaPANCAN223
# The string columns: chr11:46402624-46404139(MDK)_HypMET
# The string columns: DDX5_mut
# The string columns: chr6:85472702-85474132(TBX18)_HypMET
# The string columns: loss:cnaPANCAN287
# The string columns: chr19:37095680-37096589(ZNF529, ZNF382)_HypMET
# The string columns: loss:cnaPANCAN51
# The string columns: EPHA2_mut
# The string columns: TCF4_mut
# The string columns: loss:cnaPANCAN7 (SMARCA4)
# The string columns: gain:cnaPANCAN270 (JUN)
# The string columns: loss:cnaPANCAN99 (SOX17)
# The string columns: O
# The string columns: chr10:102756834-102759798(LZTS2)_HypMET
# The string columns: chr17:66255192-66255556(ARSG)_HypMET
# The string columns: chr3:50604905-50605359(C3orf18)_HypMET
# The string columns: chr4:83933332-83934370(LIN54)_HypMET
# The string columns: chr16:68676450-68676843(CDH3)_HypMET
# The string columns: loss:cnaPANCAN162
# The string columns: chr12:124246524-124247254(DNAH10)_HypMET
# The string columns: loss:cnaPANCAN196
# The string columns: chr7:95025559-95026122(PON3)_HypMET
# The string columns: loss:cnaPANCAN343
# The string columns: chr5:5139441-5140941(ADAMTS16)_HypMET
# The string columns: loss:cnaPANCAN119
# The string columns: loss:cnaPANCAN159
# The string columns: chr1:53308294-53309262(ZYG11A)_HypMET
# The string columns: chr5:178322713-178323538(ZFP2)_HypMET
# The string columns: gain:cnaPANCAN332
# The string columns: HLA-B_mut
# The string columns: EGFR signaling
# The string columns: DHX9_mut
# The string columns: IDH2_mut
# The string columns: BAZ2B_mut
# The string columns: chr19:37406931-37407463(ZNF829)_HypMET
# The string columns: STAG2_mut
# The string columns: loss:cnaPANCAN67
# The string columns: chr10:135123238-135123448(ZNF511, TUBGCP2)_HypMET
# The string columns: gain:cnaPANCAN247
# The string columns: gain:cnaPANCAN300
# The string columns: loss:cnaPANCAN205
# The string columns: chr11:119293320-119293943(THY1)_HypMET
# The string columns: loss:cnaPANCAN220 (HIST1H3B)
# The string columns: BRCA2_mut
# The string columns: ARID4A_mut
# The string columns: gain:cnaPANCAN84 (FGFR1,WHSC1L1)
# The string columns: chr19:57078365-57079301(ZNF470)_HypMET
# The string columns: gain:cnaPANCAN364 (STK4)
# The string columns: loss:cnaPANCAN227
# The string columns: loss:cnaPANCAN305
# The string columns: loss:cnaPANCAN104
# The string columns: APC_mut
# The string columns: CSDE1_mut
# The string columns: loss:cnaPANCAN296
# The string columns: loss:cnaPANCAN253
# The string columns: TAF1_mut
# The string columns: gain:cnaPANCAN123
# The string columns: chr10:44879714-44882391(CXCL12)_HypMET
# The string columns: Pt
# The string columns: loss:cnaPANCAN44 (BMPR1A,FAS,PTEN)
# The string columns: chr10:93392667-93393147(PPP1R3C)_HypMET
# The string columns: gain:cnaPANCAN277 (DHX9)
# The string columns: ATRX_mut
# The string columns: RTN4_mut
# The string columns: B
# The string columns: RB1_mut
# The string columns: gain:cnaPANCAN19
# The string columns: loss:cnaPANCAN76
# The string columns: chr19:51069359-51069600(LRRC4B)_HypMET
# The string columns: UPF3B_mut
# The string columns: chr8:116660432-116660747(TRPS1)_HypMET
# The string columns: loss:cnaPANCAN113
# The string columns: loss:cnaPANCAN416
# The string columns: chr6:105584148-105585621(BVES)_HypMET
# The string columns: chr3:181430141-181431076(SOX2OT, SOX2)_HypMET
# The string columns: gain:cnaPANCAN249
# The string columns: loss:cnaPANCAN167
# The string columns: gain:cnaPANCAN278 (MDM4,PIK3C2B,ZC3H11A)
# The string columns: AQR_mut
# The string columns: gain:cnaPANCAN109 (MMP2)
# The string columns: HLA-A_mut
# The string columns: loss:cnaPANCAN203
# The string columns: chr19:18118741-18119553(ARRDC2)_HypMET
# The string columns: loss:cnaPANCAN372
# The string columns: chr13:28544524-28544890(CDX2)_HypMET
# The string columns: loss:cnaPANCAN95
# The string columns: chr6:26184036-26184336()_HypMET
# The string columns: IDH1_mut
# The string columns: chr19:57831599-57832250(ZNF543)_HypMET
# The string columns: chr6:26044203-26044469(HIST1H2BB, HIST1H3C)_HypMET
# The string columns: chr15:45315201-45315543(SORD)_HypMET
# The string columns: gain:cnaPANCAN1 (CCNE1)
# The string columns: CYLD_mut
# The string columns: FBXW7_mut
# The string columns: ARHGEF6_mut
# The string columns: loss:cnaPANCAN70
# The string columns: chr2:216877899-216878352(MREG)_HypMET
# The string columns: loss:cnaPANCAN368
# The string columns: FAT2_mut
# The string columns: chr21:47602431-47602740(C21orf56)_HypMET
# The string columns: loss:cnaPANCAN341
# The string columns: bond_stereo_count
# The string columns: PML-RARA_mut
# The string columns: loss:cnaPANCAN182
# The string columns: loss:cnaPANCAN185
# The string columns: loss:cnaPANCAN72
# The string columns: chr16:56659107-56659660(MT1E)_HypMET
# The string columns: MCM8_mut
# The string columns: chr16:67464388-67465462(HSD11B2)_HypMET
# The string columns: chr19:58446336-58446800(ZNF418)_HypMET
# The string columns: gain:cnaPANCAN237
# The string columns: chr8:41507516-41507868(NKX6-3)_HypMET
# The string columns: loss:cnaPANCAN369
# The string columns: loss:cnaPANCAN14
# The string columns: loss:cnaPANCAN260
# The string columns: gain:cnaPANCAN374
# The string columns: chr6:110679417-110679833(C6orf186)_HypMET
# The string columns: gain:cnaPANCAN61
# The string columns: chr1:248020330-248021252()_HypMET
# The string columns: chr13:25670041-25670531(PABPC3)_HypMET
# The string columns: ATR_mut
# The string columns: loss:cnaPANCAN380
# The string columns: chr6:291948-292839(DUSP22)_HypMET
# The string columns: loss:cnaPANCAN97
# The string columns: chr1:2064628-2064855(PRKCZ)_HypMET
# The string columns: chr17:40274523-40275360(HSPB9, KAT2A)_HypMET
# The string columns: loss:cnaPANCAN323
# The string columns: loss:cnaPANCAN180
# The string columns: chr19:21265164-21265433(ZNF714)_HypMET
# The string columns: loss:cnaPANCAN218
# The string columns: loss:cnaPANCAN170
# The string columns: gain:cnaPANCAN280 (ARID4B,FH)
# The string columns: chr22:24384134-24384405(GSTT1)_HypMET
# The string columns: chr3:53032813-53033116(SFMBT1)_HypMET
# The string columns: chr18:32847284-32848130(ZNF397OS)_HypMET
# The string columns: ACACA_mut
# The string columns: chr19:37157632-37158119(ZNF461)_HypMET
# The string columns: chr22:39853323-39854065(MGAT3)_HypMET
# The string columns: loss:cnaPANCAN36 (RET)
# The string columns: defined_atom_stereo_count
# The string columns: gain:cnaPANCAN349 (INPP4A)
# The string columns: MECOM_mut
# The string columns: loss:cnaPANCAN336
# The string columns: ARID2_mut
# The string columns: loss:cnaPANCAN339 (ATRX)
# The string columns: DDX3X_mut
# The string columns: CDKN1B_mut
# The string columns: TMPRSS2-ERG_mut
# The string columns: chr10:64133789-64134420(ZNF365)_HypMET
# The string columns: chr11:22850765-22851367(SVIP)_HypMET
# The string columns: loss:cnaPANCAN307 (CHD3,GPS2,TP53)
# The string columns: gain:cnaPANCAN125
# The string columns: RPL5_mut
# The string columns: gain:cnaPANCAN165 (CDK4)
# The string columns: chr22:20459267-20461473()_HypMET
# The string columns: chr2:190539026-190539533(ANKAR)_HypMET
# The string columns: MTOR_mut
# The string columns: loss:cnaPANCAN250 (SRGAP3)
# The string columns: gain:cnaPANCAN89 (RAD21)
# The string columns: PGR_mut
# The string columns: RUNX1_mut
# The string columns: Other
# The string columns: loss:cnaPANCAN407
# The string columns: ZFP36L1_mut
# The string columns: loss:cnaPANCAN181
# The string columns: gain:cnaPANCAN273
# The string columns: MLL-AFF1_mut
# The string columns: chr1:10755226-10755521(CASZ1)_HypMET
# The string columns: gain:cnaPANCAN176 (CCT5,TERT,TRIO)
# The string columns: chr12:103889148-103889843(C12orf42)_HypMET
# The string columns: loss:cnaPANCAN64
# The string columns: chr1:16085147-16085862(FBLIM1)_HypMET
# The string columns: PABPC3_mut
# The string columns: loss:cnaPANCAN320
# The string columns: KEAP1_mut
# The string columns: B2M_mut
# The string columns: loss:cnaPANCAN405
# The string columns: Genome integrity
# The string columns: chr19:58125530-58125902()_HypMET
# The string columns: gain:cnaPANCAN301 (CDK12,ERBB2,MED24)
# The string columns: loss:cnaPANCAN96
# The string columns: loss:cnaPANCAN23 (SMAD4)
# The string columns: loss:cnaPANCAN111
# The string columns: CEP290_mut
# The string columns: chr10:38645112-38645513(HSD17B7P2)_HypMET
# The string columns: chr17:79818230-79819299(P4HB)_HypMET
# The string columns: PPP2R1A_mut
# The string columns: ARID4B_mut
# The string columns: VHL_mut
# The string columns: P
# The string columns: chr1:111505881-111507007(C1orf103)_HypMET
# The string columns: loss:cnaPANCAN8
# The string columns: loss:cnaPANCAN9
# The string columns: loss:cnaPANCAN114 (CIITA)
# The string columns: loss:cnaPANCAN210 (FAT1,IRF2)
# The string columns: chr8:67940691-67940997(LRRC67)_HypMET
# The string columns: chr22:46440393-46441019()_HypMET
# The string columns: chr6:3227025-3229688(TUBB2B)_HypMET
# The string columns: MSR1_mut
# The string columns: loss:cnaPANCAN229
# The string columns: loss:cnaPANCAN259
# The string columns: SETD2_mut
# The string columns: chr1:146649622-146649852(PDIA3P)_HypMET
# The string columns: chr6:105627406-105627830(POPDC3)_HypMET
# The string columns: ZC3H11A_mut
# The string columns: chr22:24372912-24373725(LOC391322)_HypMET
# The string columns: loss:cnaPANCAN48
# The string columns: gain:cnaPANCAN142
# The string columns: loss:cnaPANCAN41
# The string columns: gain:cnaPANCAN367 (ARFGAP1,GNAS)
# The string columns: gain:cnaPANCAN383
# The string columns: loss:cnaPANCAN135
# The string columns: chr2:173940414-173941271(ZAK)_HypMET
# The string columns: chr5:140305712-140307193(PCDHA7, PCDHA12, PCDHA6, PCDHAC1, PCDHA10, PCDHA4, PCDHA11, PCDHA8, PCDHA1, PCDHA2, PCDHA9, PCDHA13, PCDHA5, PCDHA3)_HypMET
# The string columns: loss:cnaPANCAN52
# The string columns: NFE2L2_mut
# The string columns: loss:cnaPANCAN50
# The string columns: chr6:6007387-6007797(NRN1)_HypMET
# The string columns: chr19:22817274-22817546(ZNF492)_HypMET
# The string columns: chr1:11724113-11724885(FBXO6, FBXO44)_HypMET
# The string columns: chr2:175546862-175547880(WIPF1)_HypMET
# The string columns: chr7:22539545-22540022(MGC87042)_HypMET
# The string columns: loss:cnaPANCAN264
# The string columns: loss:cnaPANCAN137 (POT1)
# The string columns: TCF12_mut
# The string columns: loss:cnaPANCAN221
# The string columns: chr22:24110029-24110995(CHCHD10)_HypMET
# The string columns: PSIP1_mut
# The string columns: chr16:67449936-67450472(ZDHHC1)_HypMET
# The string columns: chr3:124449178-124449461(UMPS)_HypMET
# The string columns: loss:cnaPANCAN354
# The string columns: loss:cnaPANCAN396
# The string columns: ZNRF3_mut
# The string columns: chr8:11059011-11059242(XKR6)_HypMET
# The string columns: CDH1_mut
# The string columns: LPHN2_mut
# The string columns: chr1:43613488-43613842(FAM183A)_HypMET
# The string columns: chr17:46654053-46654369(HOXB3)_HypMET
# The string columns: Other, kinases
# The string columns: loss:cnaPANCAN204
# The string columns: chr16:4166655-4167012(ADCY9)_HypMET
# The string columns: HNF1A_mut
# The string columns: MAX_mut
# The string columns: RHOA_mut
# The string columns: loss:cnaPANCAN215
# The string columns: chr11:8615397-8615889(STK33)_HypMET
# The string columns: MACF1_mut
# The string columns: loss:cnaPANCAN46
# The string columns: TSC1_mut
# The string columns: gain:cnaPANCAN271 (NOTCH2)
# The string columns: ITSN1_mut
# The string columns: HSPA8_mut
# The string columns: PI3K/MTOR signaling
# The string columns: PCDH18_mut
# The string columns: loss:cnaPANCAN102
# The string columns: ERK MAPK signaling
# The string columns: loss:cnaPANCAN233
# The string columns: gain:cnaPANCAN60
# The string columns: APAF1_mut
# The string columns: loss:cnaPANCAN103
# The string columns: PBRM1_mut
# The string columns: chr8:61193312-61194195(CA8)_HypMET
# The string columns: chr17:46673532-46674181(LOC404266)_HypMET
# The string columns: chr4:122301567-122302290(QRFPR)_HypMET
# The string columns: gain:cnaPANCAN56
# The string columns: POLR2B_mut
# The string columns: chr3:119298284-119298983(ADPRH)_HypMET
# The string columns: chr13:29292670-29293329(SLC46A3)_HypMET
# The string columns: BMPR2_mut
# The string columns: loss:cnaPANCAN120
# The string columns: AHNAK_mut
# The string columns: loss:cnaPANCAN403
# The string columns: loss:cnaPANCAN415 (B2M,BUB1B,MGA,TP53BP1)
# The string columns: gain:cnaPANCAN376
# The string columns: FAM123B_mut
# The string columns: SVEP1_mut
# The string columns: loss:cnaPANCAN255
# The string columns: FAT1_mut
# The string columns: loss:cnaPANCAN171
# The string columns: chr2:108602824-108603467(SLC5A7)_HypMET
# The string columns: EGFR_mut
# The string columns: gain:cnaPANCAN88 (PABPC1,UBR5)
# The string columns: chr9:115875199-115875738(C9orf109, C9orf110)_HypMET
# The string columns: chr7:128828333-128829366(SMO)_HypMET
# The string columns: loss:cnaPANCAN71 (EXT2)
# The string columns: ALK_mut
# The string columns: loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)
# The string columns: loss:cnaPANCAN261
# The string columns: chr5:50678632-50679375()_HypMET
# The string columns: loss:cnaPANCAN387
# The string columns: loss:cnaPANCAN360
# The string columns: gain:cnaPANCAN124 (EGFR)
# The string columns: loss:cnaPANCAN340
# The string columns: chr1:13910137-13910868(PDPN)_HypMET
# The string columns: KDR_mut
# The string columns: loss:cnaPANCAN116
# The string columns: IGFR signaling
# The string columns: LNPEP_mut
# The string columns: gain:cnaPANCAN299 (TAOK1)
# The string columns: NUP98_mut
# The string columns: MGA_mut
# The string columns: MYH9_mut
# The string columns: loss:cnaPANCAN391 (ING1,IRS2,TFDP1)
# The string columns: chr9:21974578-21975306(CDKN2A)_HypMET
# The string columns: chr10:123922850-123923542(TACC2)_HypMET
# The string columns: chr12:53448008-53448406(TENC1)_HypMET
# The string columns: loss:cnaPANCAN138
# The string columns: DICER1_mut
# The string columns: TCF3-PBX1_mut
# The string columns: chr19:12076029-12076366(ZNF763)_HypMET
# The string columns: chr10:52499392-52500021(ASAH2B)_HypMET
# The string columns: loss:cnaPANCAN197
# The string columns: SPOP_mut
# The string columns: RAC1_mut
# The string columns: chr1:220921411-220922176(MOSC2)_HypMET
# The string columns: RHOT1_mut
# The string columns: SOS2_mut
# The string columns: chr7:32996732-32997591(FKBP9)_HypMET
# The string columns: chr2:219646432-219647181(CYP27A1)_HypMET
# The string columns: loss:cnaPANCAN295 (ATP1A1,CSDE1,NRAS)
# The string columns: TCF7L2_mut
# The string columns: chr21:37442140-37442778(CBR1)_HypMET
# The string columns: LAMA2_mut
# The string columns: HDAC9_mut
# The string columns: loss:cnaPANCAN293
# The string columns: chr19:52390841-52391368(ZNF577)_HypMET
# The string columns: gain:cnaPANCAN192 (FIP1L1,PDGFRA)
# The string columns: BCR-ABL_mut
# The string columns: gain:cnaPANCAN346 (BCL11A,REL,XPO1)
# The string columns: DNA replication
# The string columns: MAGI2_mut
# The string columns: chr10:11059442-11060524(CUGBP2)_HypMET
# The string columns: gain:cnaPANCAN140 (FANCG)
# The string columns: chr7:39649253-39649510()_HypMET
# The string columns: MLLT4_mut
# The string columns: chr14:24803678-24804353(ADCY4, RIPK3)_HypMET
# The string columns: loss:cnaPANCAN40
# The string columns: ETV6-RUNX1_mut
# The string columns: chr17:52977866-52978307(TOM1L1)_HypMET
# The string columns: chr19:53073308-53074039(ZNF701)_HypMET
# The string columns: MLL2_mut
# The string columns: chr17:27503598-27504014(MYO18A)_HypMET
# The string columns: PLCB1_mut
# The string columns: loss:cnaPANCAN285
# The string columns: chr5:101632049-101632373(SLCO4C1)_HypMET
# The string columns: chr20:42543097-42545137(TOX2)_HypMET
# The string columns: loss:cnaPANCAN115
# The string columns: chr16:68002837-68003039(SLC12A4)_HypMET
# The string columns: loss:cnaPANCAN186
# The string columns: loss:cnaPANCAN131
# The string columns: NCOR1_mut
# The string columns: chr17:43339124-43339832(LOC100133991, MAP3K14, C17orf46)_HypMET
# The string columns: loss:cnaPANCAN371
# The string columns: ACVR1B_mut
# The string columns: loss:cnaPANCAN13
# The string columns: chr21:40760626-40760829(WRB)_HypMET
# The string columns: Hormone-related
# The string columns: MAP2K1_mut
# The string columns: TBL1XR1_mut
# The string columns: AHCTF1_mut
# The string columns: loss:cnaPANCAN93
# The string columns: gain:cnaPANCAN244
# The string columns: chr19:53662189-53662500(ZNF347)_HypMET
# The string columns: Chromatin histone methylation
# The string columns: FN1_mut
# The string columns: chr1:1476093-1476669(SSU72)_HypMET
# The string columns: TJP1_mut
# The string columns: gain:cnaPANCAN163 (CHD4,WNK1)
# The string columns: p53 pathway
# The string columns: SF3B1_mut
# The string columns: chr11:8102358-8102913(TUB)_HypMET
# The string columns: chr19:58399945-58400276(ZNF814)_HypMET
# The string columns: loss:cnaPANCAN193
# The string columns: loss:cnaPANCAN39
# The string columns: gain:cnaPANCAN365
# The string columns: loss:cnaPANCAN133
# The string columns: gain:cnaPANCAN58
# The string columns: loss:cnaPANCAN132
# The string columns: chr1:177150814-177151165(FAM5B)_HypMET
# The string columns: loss:cnaPANCAN288
# The string columns: chr2:201983198-201983709(CFLAR)_HypMET
# The string columns: loss:cnaPANCAN266
# The string columns: BLM_mut
# The string columns: chr18:77201938-77202732(NFATC1)_HypMET
# The string columns: NF1_mut
# The string columns: SCAI_mut
# The string columns: chr19:50831454-50832070(KCNC3)_HypMET
# The string columns: chr22:32026297-32026874(PISD)_HypMET
# The string columns: STK11_mut
# The string columns: atom_stereo_count
# The string columns: MAP3K4_mut
# The string columns: chr7:56183577-56184165(LOC389493)_HypMET
# The string columns: TGFBR2_mut
# The string columns: chr2:162270888-162271413()_HypMET
# The string columns: chr12:106532106-106533696(NUAK1)_HypMET
# The string columns: loss:cnaPANCAN157
# The string columns: loss:cnaPANCAN73
# The string columns: gain:cnaPANCAN241 (NCK1,STAG1)
# The string columns: gain:cnaPANCAN246 (SOX2)
# The string columns: CCND1_mut
# The string columns: AXIN2_mut
# The string columns: loss:cnaPANCAN33
# The string columns: loss:cnaPANCAN134
# The string columns: chr3:139258152-139258731(RBP1)_HypMET
# The string columns: chr1:57110663-57111337(PRKAA2)_HypMET
# The string columns: PLXNB2_mut
# The string columns: loss:cnaPANCAN324
# The string columns: GPS2_mut
# The string columns: loss:cnaPANCAN335
# The string columns: gain:cnaPANCAN129 (MET)
# The string columns: chr20:41817475-41819212(PTPRT)_HypMET
# The string columns: loss:cnaPANCAN322
# The string columns: loss:cnaPANCAN317
# The string columns: loss:cnaPANCAN209
# The string columns: ZNF638_mut
# The string columns: chr5:67584213-67584451(PIK3R1)_HypMET
# The string columns: CHD9_mut
# The string columns: chr16:57562451-57563325(CCDC102A)_HypMET
# The string columns: FIP1L1_mut
# The string columns: RASA1_mut
# The string columns: gain:cnaPANCAN211
# The string columns: chr11:506353-508009(RNH1)_HypMET
# The string columns: chr10:94351356-94351615(KIF11)_HypMET
# The string columns: chr2:96011132-96013197(KCNIP3)_HypMET
# The string columns: chr6:52226753-52228006()_HypMET
# The string columns: loss:cnaPANCAN2 (STK11)
# The string columns: loss:cnaPANCAN3 (GNA11)
# The string columns: loss:cnaPANCAN338
# The string columns: chr11:67070807-67071801(SSH3)_HypMET
# The string columns: CHD4_mut
# The string columns: AFF4_mut
# The string columns: chr1:150266476-150266689(MRPS21)_HypMET
# The string columns: loss:cnaPANCAN284
# The string columns: chr3:63263989-63264205(SYNPR)_HypMET
# The string columns: chr7:27195601-27196567(HOXA7)_HypMET
# The string columns: chr16:56665945-56666641(MT1M)_HypMET
# The string columns: CDC73_mut
# The string columns: loss:cnaPANCAN265
# The string columns: gain:cnaPANCAN107 (FUS,TAOK2)
# The string columns: loss:cnaPANCAN216
# The string columns: CDK12_mut
# The string columns: gain:cnaPANCAN28 (CUL2,EPC1)
# The string columns: Cytoskeleton
# The string columns: xlogp
# The string columns: gain:cnaPANCAN272 (PIP5K1A,SETDB1)
# The string columns: gain:cnaPANCAN384 (ERCC5,ING1,IRS2,TFDP1)
# The string columns: gain:cnaPANCAN127 (AKAP9)
# The string columns: chr22:48970857-48972947(FAM19A5)_HypMET
# The string columns: loss:cnaPANCAN169
# The string columns: loss:cnaPANCAN378 (ZNRF3)
# The string columns: CHEK2_mut
# The string columns: loss:cnaPANCAN425
# The string columns: loss:cnaPANCAN101
# The string columns: gain:cnaPANCAN243
# The string columns: chr3:9956822-9957664(IL17RE)_HypMET
# The string columns: EP300_mut
# The string columns: loss:cnaPANCAN161 (NOTCH1)
# The string columns: chr7:35292985-35294674(TBX20)_HypMET
# The string columns: loss:cnaPANCAN172
# The string columns: BRCA1_mut
# The string columns: NTRK2_mut
# The string columns: loss:cnaPANCAN355
# The string columns: chr17:6558221-6558441()_HypMET
# The string columns: chr18:77196121-77196568(NFATC1)_HypMET
# The string columns: chr15:30114110-30115215(TJP1)_HypMET
# The string columns: chr20:33146135-33147318(MAP1LC3A)_HypMET
# The string columns: loss:cnaPANCAN228
# The string columns: ERBB3_mut
# The string columns: molecular_weight
# The string columns: chr8:79428433-79428754(PKIA)_HypMET
# The string columns: CUL3_mut
# The string columns: loss:cnaPANCAN65
# The string columns: loss:cnaPANCAN32
# The string columns: ZFHX3_mut
# The string columns: loss:cnaPANCAN5
# The string columns: H
# The string columns: gain:cnaPANCAN411 (BLM,CRTC3,FANCI,IDH2,NR2F2,PCSK6)
# The string columns: CAD_mut
# The string columns: BRAF_mut
# The string columns: SETDB1_mut
# The string columns: loss:cnaPANCAN16
# The string columns: MYH11_mut
# The string columns: loss:cnaPANCAN419
# The string columns: loss:cnaPANCAN222
# The string columns: loss:cnaPANCAN94
# The string columns: gain:cnaPANCAN375
# The string columns: gain:cnaPANCAN212 (HSP90AB1,TRERF1)
# The string columns: rotatable_bond_count
# The string columns: loss:cnaPANCAN424
# The string columns: chr6:48036137-48036410(C6orf138)_HypMET
# The string columns: chr9:123555399-123555899(FBXW2)_HypMET
# The string columns: AKAP9_mut
# The string columns: ELF3_mut
# The string columns: ZFP36L2_mut
# The string columns: SRGAP3_mut
# The string columns: chr10:135122851-135123109(ZNF511, TUBGCP2)_HypMET
# The string columns: loss:cnaPANCAN294
# The string columns: RBM5_mut
# The string columns: loss:cnaPANCAN327
# The string columns: loss:cnaPANCAN6
# The string columns: chr11:43902254-43902528(ALKBH3)_HypMET
# The string columns: chr19:22018594-22018827(ZNF43)_HypMET
# The string columns: h_bond_acceptor_count
# The string columns: loss:cnaPANCAN282
# The string columns: NSD1_mut
# The string columns: loss:cnaPANCAN62 (HRAS,IRF7)
# The string columns: chr1:143912736-143916156(FAM72D)_HypMET
# The string columns: loss:cnaPANCAN151
# The string columns: chr1:218520287-218520506(TGFB2)_HypMET
# The string columns: CNOT1_mut
# The string columns: chr22:47022457-47022659()_HypMET
# The string columns: chr19:52531323-52531724(ZNF614)_HypMET
# The string columns: KDM6A_mut
# The string columns: loss:cnaPANCAN370
# The string columns: loss:cnaPANCAN45
# The string columns: loss:cnaPANCAN158
# The string columns: loss:cnaPANCAN168
# The string columns: loss:cnaPANCAN410
# The string columns: chr5:73935725-73937551(ENC1)_HypMET
# The string columns: SRGAP1_mut
# The string columns: loss:cnaPANCAN112 (CREBBP)
# The string columns: loss:cnaPANCAN183
# The string columns: chr20:30192854-30194025(ID1)_HypMET
# The string columns: STIP1_mut
# The string columns: loss:cnaPANCAN318
# The string columns: gain:cnaPANCAN366
# The string columns: loss:cnaPANCAN217
# The string columns: chr17:44656490-44657494(ARL17A)_HypMET
# The string columns: ACVR2A_mut
# The string columns: gain:cnaPANCAN245 (MECOM)
# The string columns: RBM10_mut
# The string columns: loss:cnaPANCAN408
# The string columns: loss:cnaPANCAN173
# The string columns: DLG1_mut
# The string columns: complexity
# The string columns: undefined_atom_stereo_count
# The string columns: EZH2_mut
# The string columns: chr10:105253191-105254428(NEURL)_HypMET
# The string columns: chr6:27858166-27858564()_HypMET
# The string columns: F8_mut
# The string columns: WT1_mut
# The string columns: loss:cnaPANCAN319
# The string columns: chr6:150067323-150067766(NUP43)_HypMET
# The string columns: chr8:107669777-107670591(OXR1)_HypMET
# The string columns: NUP93_mut
# The string columns: chr1:53904140-53905247(FLJ40434)_HypMET
# The string columns: ABL2_mut
# The string columns: gain:cnaPANCAN363 (ASXL1)
# The string columns: loss:cnaPANCAN145 (FANCG,PAX5)
# The string columns: loss:cnaPANCAN42 (ANK3)
# The string columns: chr16:48399730-48400040(SIAH1)_HypMET
# The string columns: loss:cnaPANCAN175
# The string columns: chr1:171810467-171811325(DNM3)_HypMET
# The string columns: CDC27_mut
# The string columns: chr3:53527927-53530106(CACNA1D)_HypMET
# The string columns: gain:cnaPANCAN190 (FGFR3,WHSC1)
# The string columns: gain:cnaPANCAN87
# The string columns: ARAP3_mut
# The string columns: chr5:126626053-126626901(MEGF10)_HypMET
# The string columns: CLOCK_mut
# The string columns: loss:cnaPANCAN184 (APC)
# The string columns: MCM3_mut
# The string columns: TRIO_mut
# The string columns: chr11:73693702-73694802(UCP2)_HypMET
# The string columns: chr8:67344497-67344989(RRS1)_HypMET
# The string columns: SMARCB1_mut
# The string columns: loss:cnaPANCAN79
# The string columns: loss:cnaPANCAN267
# The string columns: gain:cnaPANCAN330 (RPGR)
# The string columns: loss:cnaPANCAN152
# The string columns: AXIN1_mut
# The string columns: CTNNB1_mut
# The string columns: chr4:76555366-76556079(CDKL2)_HypMET
# The string columns: gain:cnaPANCAN236
# The string columns: loss:cnaPANCAN328
# The string columns: loss:cnaPANCAN292
# The string columns: gain:cnaPANCAN83
# The string columns: chr5:1594238-1595027(SDHAP3)_HypMET
# The string columns: chr17:46691520-46692097(HOXB8)_HypMET
# The string columns: loss:cnaPANCAN306
# The string columns: loss:cnaPANCAN353
# The string columns: chr19:1851578-1852203()_HypMET
# The string columns: chr2:74875128-74875562(C2orf65)_HypMET
# The string columns: chr2:29337983-29338909(CLIP4)_HypMET
# The string columns: loss:cnaPANCAN226
# The string columns: chr6:55443732-55444092(HMGCLL1)_HypMET
# The string columns: chr19:40871617-40871824(PLD3)_HypMET
# The string columns: loss:cnaPANCAN290
# The string columns: loss:cnaPANCAN232
# The string columns: gain:cnaPANCAN275 (SDHC)
# The string columns: chr20:48098512-48099560(KCNB1)_HypMET
# The string columns: ARFGAP3_mut
# The string columns: HRAS_mut
# The string columns: ARHGAP29_mut
# The string columns: loss:cnaPANCAN74
# The string columns: loss:cnaPANCAN224
# The string columns: loss:cnaPANCAN187
# The string columns: loss:cnaPANCAN146 (GNAQ,NTRK2,PCSK5,TJP2)
# The string columns: gain:cnaPANCAN86
# The string columns: gain:cnaPANCAN166 (MDM2,NUP107,SRGAP1)
# The string columns: gain:cnaPANCAN164 (KRAS)
# The string columns: chr9:98783216-98784364(NCRNA00092)_HypMET
# The string columns: chr7:87256958-87258444(RUNDC3B, ABCB1)_HypMET
# The string columns: loss:cnaPANCAN82
# The string columns: loss:cnaPANCAN230 (SYNCRIP,ZNF292)
# The string columns: PIK3CA_mut
# The string columns: chr3:42304944-42305311(CCK)_HypMET
# The string columns: chr11:72463092-72463717(ARAP1)_HypMET
# The string columns: loss:cnaPANCAN37
# The string columns: gain:cnaPANCAN121 (ACTB,CARD11,PMS2,RAC1)
# The string columns: loss:cnaPANCAN155
# The string columns: chr3:10206449-10207024(IRAK2)_HypMET
# The string columns: loss:cnaPANCAN153 (ABL1)
# The string columns: ABL signaling
# The string columns: MKL1_mut
# The string columns: loss:cnaPANCAN406
# The string columns: BRWD1_mut
# The string columns: loss:cnaPANCAN189
# The string columns: FXR1_mut
# The string columns: chr8:61626645-61627074(CHD7)_HypMET
# The string columns: loss:cnaPANCAN207
# The string columns: chr19:54371854-54372990(MYADM)_HypMET
# The string columns: chr4:6200912-6202724(JAKMIP1)_HypMET
# The string columns: loss:cnaPANCAN315 (NF1,SUZ12)
# The string columns: 3bonds
# The string columns: SOS1_mut
# The string columns: gain:cnaPANCAN302 (CLTC,PPM1D)
# The string columns: chr1:42127380-42128632(HIVEP3)_HypMET
# The string columns: gain:cnaPANCAN141 (GNAQ,NTRK2,PCSK5,TJP2)
# The string columns: gain:cnaPANCAN274
# The string columns: gain:cnaPANCAN238
# The string columns: ERBB2_mut
# The string columns: loss:cnaPANCAN414
# The string columns: chr15:93198374-93199181(FAM174B)_HypMET
# The string columns: chr17:38333605-38334795(RAPGEFL1)_HypMET
# The string columns: chr11:64509433-64513826(RASGRP2)_HypMET
# The string columns: loss:cnaPANCAN420
# The string columns: SPTAN1_mut
# The string columns: chr4:66535193-66535620(EPHA5)_HypMET
# The string columns: CDKN1A_mut
# The string columns: chr15:81426499-81426702(C15orf26)_HypMET
# The string columns: WHSC1L1_mut
# The string columns: gain:cnaPANCAN352 (PMS1)
# The string columns: chr9:35756948-35757339(MSMP)_HypMET
# The string columns: CLSPN_mut
# The string columns: chr2:85811340-85811855(VAMP5)_HypMET
# The string columns: chr6:26250436-26250827(HIST1H2BH, HIST1H3F)_HypMET
# The string columns: gain:cnaPANCAN350
# The string columns: TP53BP1_mut
# The string columns: loss:cnaPANCAN423
# The string columns: chr4:102711829-102712199(BANK1)_HypMET
# The string columns: chr7:750788-751237(PRKAR1B)_HypMET
# The string columns: loss:cnaPANCAN252
# The string columns: loss:cnaPANCAN281 (RPL22)
# The string columns: chr1:145472980-145474702(ANKRD34A)_HypMET
# The string columns: loss:cnaPANCAN325
# The string columns: gain:cnaPANCAN395 (AKT1,HSP90AA1,PPP2R5C)
# The string columns: loss:cnaPANCAN412
# The string columns: chr1:121260857-121261525(LOC647121)_HypMET
# The string columns: WNK1_mut
# The string columns: loss:cnaPANCAN156
# The string columns: RNF43_mut
# The string columns: SACS_mut
# The string columns: FRG1B_mut
# The string columns: chr11:65408344-65408631(SIPA1)_HypMET
# The string columns: PTPRU_mut
# The string columns: gain:cnaPANCAN85 (SOX17)
# The string columns: MLH3_mut
# The string columns: loss:cnaPANCAN15
# The string columns: chr2:232650898-232651431(COPS7B)_HypMET
# The string columns: chr5:175792355-175793505(ARL10)_HypMET
# The string columns: CASP8_mut
# The string columns: MAP3K1_mut
# The string columns: chr1:40782220-40783145(COL9A2)_HypMET
# The string columns: TJP2_mut
# The string columns: chr1:21996161-21996409(RAP1GAP)_HypMET
# The string columns: chr18:14132000-14132482(ZNF519)_HypMET
# The string columns: loss:cnaPANCAN17
# The string columns: loss:cnaPANCAN136
# The string columns: loss:cnaPANCAN26
# The string columns: TP53_mut
# The string columns: gain:cnaPANCAN108 (CHD9,CYLD)
# The string columns: loss:cnaPANCAN81
# The string columns: MEN1_mut
# The string columns: loss:cnaPANCAN388
# The string columns: chr19:58144339-58144999(ZNF211)_HypMET
# The string columns: loss:cnaPANCAN422
# The string columns: NF2_mut
# The string columns: loss:cnaPANCAN234
# The string columns: gain:cnaPANCAN191 (FIP1L1,PDGFRA)
# The string columns: chr19:12266998-12267686(ZNF625)_HypMET
# The string columns: loss:cnaPANCAN286
# The string columns: loss:cnaPANCAN310 (MAP2K4)
# The string columns: chr17:66596072-66597578(FAM20A)_HypMET
# The string columns: chr14:23834435-23835947(EFS)_HypMET
# The string columns: SMC1A_mut
# The string columns: chr9:140310894-140312457(EXD3)_HypMET
# The string columns: chr15:60690708-60690930(ANXA2)_HypMET
# The string columns: loss:cnaPANCAN402
# The string columns: chr4:129208297-129209780(PGRMC2)_HypMET
# The string columns: loss:cnaPANCAN308
# The string columns: chr10:106028542-106029047(GSTO2)_HypMET
# The string columns: STAG1_mut
# The string columns: chr1:120835961-120839391(FAM72B)_HypMET
# The string columns: CHD8_mut
# The string columns: loss:cnaPANCAN12
# The string columns: gain:cnaPANCAN139
# The string columns: RGS3_mut
# The string columns: SMARCA1_mut
# The string columns: loss:cnaPANCAN379
# The string columns: gain:cnaPANCAN248 (EIF4A2,RFC4)
# The string columns: chr7:27186927-27187692(HOXA6)_HypMET
# The string columns: loss:cnaPANCAN69
# The string columns: loss:cnaPANCAN398
# The string columns: gain:cnaPANCAN91 (MYC)
# The string columns: CREBBP_mut
# The string columns: gain:cnaPANCAN178
# The string columns: gain:cnaPANCAN143 (NOTCH1)
# The string columns: chr3:10857687-10858447(SLC6A11)_HypMET
# The string columns: heavy_atom_count
# The string columns: chr10:43891546-43892917(HNRNPF)_HypMET
# The string columns: chr15:45722561-45722939()_HypMET
# The string columns: chr2:9346383-9347944(ASAP2)_HypMET
# The string columns: CHD6_mut
# The string columns: ZNF292_mut
# The string columns: gain:cnaPANCAN90
# The string columns: CUX1_mut
# The string columns: chr1:181451311-181452049()_HypMET
# The string columns: chr4:5709985-5710495(EVC2)_HypMET
# The string columns: loss:cnaPANCAN342
# The string columns: chr6:29759946-29760903(HCG4)_HypMET
# The string columns: MAP2K4_mut
# The string columns: loss:cnaPANCAN206
# The string columns: MYCN_mut
# The string columns: chr5:157002174-157003182(ADAM19)_HypMET
# The string columns: chr17:42092143-42092432(TMEM101)_HypMET
# The string columns: chr7:100136448-100136919(AGFG2)_HypMET
# The string columns: chr8:22422534-22423702(SORBS3)_HypMET
# The string columns: loss:cnaPANCAN35 (CUL2)
# The string columns: gain:cnaPANCAN126
# The string columns: MAP4K3_mut
# The string columns: chr6:26188997-26189295(HIST1H4D)_HypMET
# The string columns: Cl
# The string columns: MAX_CONC
# The string columns: chr15:30685087-30685891(CHRFAM7A)_HypMET
# The string columns: gain:cnaPANCAN276
# The string columns: loss:cnaPANCAN258
# The string columns: loss:cnaPANCAN321
# The string columns: chr2:136499145-136500144(UBXN4)_HypMET
# The string columns: loss:cnaPANCAN198
# The string columns: chr2:218621279-218621498(DIRC3)_HypMET
# The string columns: MED12_mut
# The string columns: loss:cnaPANCAN208 (PCDH18)
# The string columns: loss:cnaPANCAN30 (LARP4B)
# The string columns: chr1:33938025-33938328(ZSCAN20)_HypMET
# The string columns: SEC31A_mut
# The string columns: chr11:66247269-66248249(DPP3)_HypMET
# The string columns: MET_mut
# The string columns: loss:cnaPANCAN75 (MED17)
# The string columns: chr2:152954633-152955784(CACNB4)_HypMET
# The string columns: chr14:61188116-61190772(SIX4)_HypMET
# The string columns: loss:cnaPANCAN256 (CACNA1D,WNT5A)
# The string columns: loss:cnaPANCAN263
# The string columns: loss:cnaPANCAN31
# The string columns: PCSK5_mut
# The string columns: chr19:11998804-11999131(ZNF69)_HypMET
# The string columns: loss:cnaPANCAN200
# The string columns: INPP4A_mut
# The string columns: TAOK1_mut
# The string columns: chr6:39901852-39902299(MOCS1)_HypMET
# The string columns: FGFR2_mut
# The string columns: chr17:41363727-41364273(TMEM106A)_HypMET
# The string columns: loss:cnaPANCAN404
# The string columns: gain:cnaPANCAN29 (KAT6B)
# The string columns: AMOT_mut
# The string columns: ARID1B_mut
# The string columns: FOXP1_mut
# The string columns: chr19:48949034-48949442(GRWD1)_HypMET
# The string columns: NTN4_mut
# The string columns: chr11:44087518-44088165(ACCS)_HypMET
# The string columns: ROBO2_mut
# The string columns: gain:cnaPANCAN105
# The string columns: loss:cnaPANCAN55
# The string columns: loss:cnaPANCAN4
# The string columns: loss:cnaPANCAN24
# The string columns: CNOT3_mut
# The string columns: loss:cnaPANCAN337
# The string columns: INPPL1_mut
# The string columns: loss:cnaPANCAN409
# The string columns: loss:cnaPANCAN20
# The string columns: chr19:12831793-12832225(TNPO2)_HypMET
# The string columns: ASH1L_mut
# The string columns: chr19:47731377-47731715(BBC3)_HypMET
# The string columns: MLL3_mut
# The string columns: loss:cnaPANCAN312
# The string columns: IREB2_mut
# The string columns: loss:cnaPANCAN309
# The string columns: chr19:11689417-11689768(ACP5)_HypMET
# The string columns: loss:cnaPANCAN179
# The string columns: THRAP3_mut
# The string columns: EIF4G1_mut
# The string columns: PIK3R1_mut
# The string columns: chr19:48945800-48947636(GRIN2D)_HypMET
# The string columns: chr19:56915356-56915856(ZNF583)_HypMET
# The string columns: PLXNA1_mut
# The string columns: chr1:248100325-248100726(OR2L13)_HypMET
# The string columns: Metabolism
# The string columns: chr6:31148369-31148577(PSORS1C3)_HypMET
# The string columns: COL1A1_mut
# The string columns: chr9:4984543-4985630(JAK2)_HypMET
# The string columns: DHX15_mut
# The string columns: chr5:125930601-125931049(ALDH7A1)_HypMET
# The string columns: loss:cnaPANCAN304
# The string columns: loss:cnaPANCAN283
# The string columns: EIF4G3_mut
# The string columns: chr1:110230238-110230614(GSTM1)_HypMET
# The string columns: MED23_mut
# The string columns: chr20:61636171-61639055()_HypMET
# The string columns: loss:cnaPANCAN110
# The string columns: SIN3A_mut
# The string columns: chr17:40932329-40933299(WNK4)_HypMET
# The string columns: gain:cnaPANCAN239 (FOXP1,MITF)
# The string columns: CUL2_mut
# The string columns: chr18:77193463-77193764(NFATC1)_HypMET
# The string columns: DNMT3A_mut
# The string columns: loss:cnaPANCAN313
# The string columns: chr21:47601020-47601229(C21orf56)_HypMET
# The string columns: loss:cnaPANCAN117 (CHD9,CNOT1,CYLD,MMP2,NUP93)
# The string columns: loss:cnaPANCAN400
# The string columns: chr3:187456250-187456580(BCL6)_HypMET
# The string columns: BPTF_mut
# The string columns: PTEN_mut
# The string columns: BCOR_mut
# The string columns: F
# The string columns: CLASP2_mut
# The string columns: NOTCH1_mut
# The string columns: loss:cnaPANCAN235 (ARID1B,MAP3K4,MLLT4)
# The string columns: loss:cnaPANCAN390
# The string columns: PTPN11_mut
# The string columns: chr22:24180491-24181666(DERL3)_HypMET
# The string columns: CCAR1_mut
# The string columns: chr3:36985540-36987041(TRANK1)_HypMET
# The string columns: KALRN_mut
# The string columns: loss:cnaPANCAN54
# The string columns: chr3:125075915-125076481(ZNF148)_HypMET
# The string columns: loss:cnaPANCAN231
# The string columns: PHF6_mut
# The string columns: PHLPP1_mut
# The string columns: loss:cnaPANCAN49
# The string columns: gain:cnaPANCAN214
# The string columns: ZMYM2_mut
# The string columns: chr14:24457864-24458100(DHRS4L2)_HypMET
# The string columns: EWSR1-FLI1_mut
# The string columns: G3BP2_mut
# The string columns: loss:cnaPANCAN202
# The string columns: RPGR_mut
# The string columns: WNT signaling
# The string columns: CIC_mut
# The string columns: chr5:180017099-180019062(SCGB3A1)_HypMET
# The string columns: loss:cnaPANCAN80 (SDHD)
# The string columns: Apoptosis regulation
# The string columns: loss:cnaPANCAN326 (SOX9)
# The string columns: SMARCA4_mut
# The string columns: 2bonds
# The string columns: gain:cnaPANCAN57 (CAT)
# The string columns: CHD3_mut
# The string columns: CTNND1_mut
# The string columns: loss:cnaPANCAN421
# The string columns: LIMA1_mut
# The string columns: BAP1_mut
# The string columns: chr7:27203915-27206462(HOXA9)_HypMET
# The string columns: XPO1_mut
# The string columns: chr16:67183208-67184968(B3GNT9)_HypMET
# The string columns: MLH1_mut
# The string columns: BCLAF1_mut
# The string columns: chr6:90142751-90143635(ANKRD6)_HypMET
# The string columns: Protein stability and degradation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-435aa5868351> in <module>()
#      12 results = TuneParameters(train, 4, kernels = kernels_to_test, column_not_to_use=column_not_to_use,
#      13                          features_to_scale=columns_for_normalisation, scaling = True,
# ---> 14                          print_results=False)
#      15
#      16 print("Tuned parameters:")
#
# <ipython-input-4-6a6c9965ce86> in TuneParameters(train, number_coefficients, kernels, column_not_to_use, param_tested, param_tested_values, alpha, gamma, degree, coef0, features_to_scale, scaling, print_results)
#     222                                             param_tested = "alpha", param_tested_values = [0.1, 0.5, 1, 5, 7, 10, 30, 50, 100, 200, 300, 500],
#     223                                             features_to_scale = features_to_scale, scaling = scaling,
# --> 224                                             print_results=print_results)
#     225
#     226             print("\n%s kernel: Execution time: %.3f seconds \n" % (kernel, (time.time() - start_time)))
#
# <ipython-input-4-6a6c9965ce86> in RunCrossValidation(train, number_coefficients, column_not_to_use, kernel, param_tested, param_tested_values, alpha, gamma, degree, coef0, features_to_scale, scaling, print_results)
#     127
#     128             # mse is more sensitive to different parameters choice
# --> 129             mse = LeaveOneOutError(kernel_model, X_train, y_train, metrics="mse")
#     130             df_errors.loc["mse", "mse_coef"+str(i+1)+"_"+str(param)] = mse
#     131
#
# <ipython-input-4-6a6c9965ce86> in LeaveOneOutError(kernel_model, X, y, metrics)
#      37         y_train_loo, y_test_loo = y[train_index], y[test_index]
#      38
# ---> 39         model = kernel_model.fit(X_train_loo, y_train_loo)
#      40         if metrics == "mse":
#      41             mse = mean_squared_error(y_test_loo, model.predict(X_test_loo))
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/kernel_ridge.py in fit(self, X, y, sample_weight)
#     150         # Convert data
#     151         X, y = check_X_y(X, y, accept_sparse=("csr", "csc"), multi_output=True,
# --> 152                          y_numeric=True)
#     153         if sample_weight is not None and not isinstance(sample_weight, float):
#     154             sample_weight = check_array(sample_weight, ensure_2d=False)
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~/.conda/envs/jupyter-spark/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Microtubule stabiliser'

# %%
len(train.columns[2:])
# Out:
# 1154

# %%
df = pd.read_csv(_FOLDER+'merged_fitted_sigmoid4_123_with_drugs_properties.csv')

potential_columns_for_normalisation = []
for col in df.columns:
    if (df[col].nunique()>2) & (df[col].dtype != "O"):
        potential_columns_for_normalisation.append(col)
        
columns_for_normalisation = list(set(potential_columns_for_normalisation) - set(norm_response) - set(param1) - set(param2) -set(['Unnamed: 0', 'DRUG_ID', 'COSMIC_ID',]))
columns_for_normalisation
# Out:
# ['atom_stereo_count',
#  'rotatable_bond_count',
#  'h_bond_acceptor_count',
#  'defined_atom_stereo_count',
#  'complexity',
#  'xlogp',
#  'heavy_atom_count',
#  'undefined_atom_stereo_count',
#  'covalent_unit_count',
#  'surface_area',
#  'bond_stereo_count',
#  '2bonds',
#  'molecular_weight']

# %%
"atom_stereo_count" in train.columns
# Out:
# True

# %%
potential_columns_for_normalisation = []
for col in train.columns:
    if (train[col].nunique()>2) & (train[col].dtype != "O"):
        potential_columns_for_normalisation.append(col)
potential_columns_for_normalisation
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'COSMIC_ID',
#  'norm_cells_1',
#  'norm_cells_2',
#  'norm_cells_3',
#  'norm_cells_4',
#  'norm_cells_5',
#  'norm_cells_6',
#  'norm_cells_7',
#  'norm_cells_8',
#  'norm_cells_9',
#  'param_1',
#  'param_2',
#  'param_3',
#  'param_4']

# %%
train["atom_stereo_count"]
# Out:
# 0     11.0
# 1     11.0
# 2     11.0
# 3     11.0
# 4     11.0
# 5     11.0
# 6     11.0
# 7     11.0
# 8     11.0
# 9     11.0
# 10    11.0
# Name: atom_stereo_count, dtype: float64

# %%
train.shape
# Out:
# (11, 1156)
